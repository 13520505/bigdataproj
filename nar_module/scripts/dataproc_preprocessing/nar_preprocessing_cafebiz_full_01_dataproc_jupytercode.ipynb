# %% [markdown]
# ### Setup (only required for the first run on the Spark cluster)

# %% [raw]
# input:  file  cafebiz_articles.csv, file log join with dbnews to have id

# %%
# !pip install pandas

# %%
ROOT_PATH = '/data/tungtv/Code/dataset/dataset_cafebiz_full_45/'
#TODO: Upload this file (generated by the ACR module training) to GCS before calling spark script
# !gsutil cp {ROOT_PATH}/adressa_articles.csv.

# %% [markdown]
# ### Loading dependencies

# %%
import os
import json
import pandas as pd
import pickle
import datetime
import hashlib
import math
import matplotlib
# %matplotlib inline

# %%
import findspark
findspark.init()
import pyspark
import pyspark.sql.functions as F
import pyspark.sql.types as T
from pyspark import SparkContext,SparkConf,SQLContext
from pyspark.sql import SparkSession
# from pyspark.sql.functions import pandas_udf
# from pyspark.sql.functions import PandasUDFType
from pyspark.sql.functions import *

# %%
spark = SparkSession.builder.master('local[*]').appName('myAppName')\
.config("spark.local.dir","/data/tungtv/tmp/").getOrCreate()

# %%
sc = spark.sparkContext
sqlContext = SQLContext(sc)

# %%
print(spark.version)
# Out:
# 2.2.0

# %% [markdown]
# ## Loading articles pre-processed

# %%
articles_original_df = pd.read_csv('/data/tungtv/Code/dataset/dataset_cafebiz_full_45/cafebiz_articles.csv')

# %%
articles_original_df.columns
# Out:
# Index(['id', 'content', 'created_at_ts', 'teaser', 'domain', 'keywords',
#        'title', 'url', 'category0', 'persons', 'locations', 'text_highlights',
#        'id_encoded', 'category0_encoded', 'keywords_encoded',
#        'locations_encoded', 'persons_encoded'],
#       dtype='object')

# %%
articles_original_df['url'][0]
# Out:
# 'http://cafebiz.vn/gia-dinh-ty-phu-gop-113-trieu-usd-khoi-phuc-nha-tho-duc-ba-paris-giau-co-va-quyen-luc-co-nao-20190416190831.chn'

# %%
valid_articles_urls_to_ids_dict = dict(articles_original_df[['url','id_encoded']].apply(lambda x: (x['url'], x['id_encoded']), axis=1).values)
valid_articles_urls_to_ids_dict
# Out:
# {'http://cafebiz.vn/gia-dinh-ty-phu-gop-113-trieu-usd-khoi-phuc-nha-tho-duc-ba-paris-giau-co-va-quyen-luc-co-nao-20190416190831.chn': 1,
#  'http://cafebiz.vn/4-cong-trinh-lich-su-tai-chau-au-tung-bi-quy-lua-tan-cong-nhu-nha-tho-duc-ba-paris-20190416191427.chn': 2,
#  'http://cafebiz.vn/tot-nghiep-dh-roi-chay-grab-2-nam-chang-trai-gay-tranh-cai-vi-quan-diem-ha-noi-khong-danh-cho-nhung-ke-sinh-ra-tu-lang-nhu-chung-ta-20190420083631.chn': 3,
#  'http://cafebiz.vn/thanh-nien-30-tuoi-con-an-bam-bo-me-song-nho-tro-cap-that-nghiep-tro-thanh-trieu-phu-cha-de-cua-tua-game-pubg-ty-do-20190429095142.chn': 4,
#  'http://cafebiz.vn/steve-jobs-co-1-thoi-quen-ma-bat-cu-nguoi-thanh-cong-nao-cung-thuong-lam-nghe-qua-ai-cung-tuong-de-nhung-chi-khi-bat-dau-moi-thay-kho-vo-cung-20190429154619.chn': 5,
#  'http://cafebiz.vn/gia-bitcoin-tang-vot-20190503135004.chn': 6,
#  'http://cafebiz.vn/chiem-nguong-ca-tram-ngoi-nha-duoc-xay-noi-tren-mat-nuoc-quan-the-kien-truc-dang-tu-hao-cua-amsterdam-20190507134028.chn': 7,
#  'http://cafebiz.vn/lan-song-dich-chuyen-fdi-tu-trung-quoc-ve-viet-nam-tang-manh-co-phieu-ha-tang-khu-cong-nghiep-tang-truong-phi-ma-20190515084449.chn': 8,
#  'http://cafebiz.vn/bs-khuyen-cao-uong-1-lon-nuoc-ngot-ngay-ung-thu-xuat-hien-som-ac-tinh-hoa-nhanh-20190516163024.chn': 9,
#  'http://cafebiz.vn/hanh-trinh-tu-mot-ke-tu-phu-den-mot-ty-phu-ceo-va-nguoi-dong-sang-lap-tre-tuoi-nhat-cua-isarel-tao-nen-startup-ty-do-wework-20190518101359.chn': 10,
#  'http://cafebiz.vn/nam-ngoai-ngheo-bao-nhieu-nam-nay-duoc-den-dap-bay-nhieu-trong-7-thang-toi-3-con-giap-nay-phat-tai-khong-ngung-cuoi-nam-cuoc-song-vien-man-20190519133339.chn': 11,
#  'http://cafebiz.vn/9-su-that-chung-ta-ai-cung-tin-tu-be-nhung-hoa-ra-lai-sai-be-bet-20190520091652.chn': 12,
#  'http://cafebiz.vn/ngam-cay-cau-day-vang-5700-ty-dong-lon-thu-hai-song-hau-noi-can-tho-voi-dong-thap-20190520092338.chn': 13,
#  'http://cafebiz.vn/muon-nhan-tai-trong-cong-ty-khong-ra-di-sep-hay-can-trong-6-truong-hop-sau-20190520102244.chn': 14,
#  'http://cafebiz.vn/tro-thanh-ty-phu-usd-chi-nho-mot-dong-tweet-20190521084507.chn': 15,
#  'http://cafebiz.vn/dia-oc-alibaba-van-no-tung-bung-20190522090738.chn': 16,
#  'http://cafebiz.vn/cuoc-tan-cong-cua-my-vao-huawei-la-sai-lam-nghiem-trong-20190523083237.chn': 17,
#  'http://cafebiz.vn/de-xuat-han-muc-giao-dich-qua-vi-dien-tu-khong-qua-20-trieu-dong-ngay-muon-dat-coc-xe-vinfast-mua-tour-di-han-sam-smart-tv-se-khong-the-thanh-toan-qua-momo-moca-vnpay-20190525120805.chn': 18,
#  'http://cafebiz.vn/startup-dai-loan-cho-phep-du-khach-dat-tour-trai-nghiem-truot-tuyet-va-boi-cung-ca-map-vao-phut-chot-khoi-hanh-tham-vong-thanh-cong-ty-du-lich-so-1-chau-a-201904081701292.chn': 19,
#  'http://cafebiz.vn/cuoc-chien-0-dong-phi-dich-vu-ngan-hang-bat-dau-201904100851059.chn': 20,
#  'http://cafebiz.vn/39-tuoi-bat-ngo-bi-duoi-viec-michael-bloomberg-da-lam-dieu-an-tuong-nay-de-lat-nguoc-the-co-do-cung-chinh-la-dieu-ban-nhat-dinh-phai-co-neu-muon-thanh-cong-201904160913535.chn': 21,
#  'http://cafebiz.vn/quyen-luc-cua-apple-dai-dien-cho-suc-manh-xu-ly-cua-android-cuoi-cung-lai-can-iphone-de-thang-hoa-201904171726246.chn': 22,
#  'http://cafebiz.vn/nho-instagram-nguoi-phu-nu-nay-nay-ra-y-tuong-doc-dao-cho-quan-ca-phe-va-da-thanh-cong-ngoai-mong-doi-201904201009495.chn': 23,
#  'http://cafebiz.vn/he-lo-mot-loat-chi-tiet-bat-ngo-ve-hoang-tu-be-george-dang-sau-ve-ngoai-it-noi-nhut-nhat-la-mot-cau-be-hoan-toan-khac-biet-201904210933003.chn': 24,
#  'http://cafebiz.vn/vi-sao-mot-danh-hai-chua-tung-tham-gia-chinh-tri-lai-thang-ap-dao-truoc-tong-thong-ukraine-201904222010234.chn': 25,
#  'http://cafebiz.vn/nhon-nhip-giao-dich-nha-dat-tai-nhon-trach-dong-nai-phong-cong-chung-qua-tai-201904240826053.chn': 26,
#  'http://cafebiz.vn/con-quan-duoc-nang-diem-uy-ban-kiem-tra-nen-vao-cuoc-201904240831198.chn': 27,
#  'http://cafebiz.vn/dieu-gi-tao-nen-mot-quoc-gia-dang-cap-the-gioi-khong-phai-la-do-nen-kinh-te-manh-hay-co-bao-nhieu-ti-phu-xay-duoc-nhieu-toa-nha-cao-tang-ma-la-do-dieu-nay-201904292038385.chn': 28,
#  'http://cafebiz.vn/xuat-khau-tai-hoa-ky-bi-quyet-vi-dieu-giup-cac-doanh-nghiep-viet-nam-vuot-qua-hang-rao-phong-ve-thuong-mai-trung-trung-diep-diep-201905010002528.chn': 29,
#  'http://cafebiz.vn/nasa-dang-phat-trien-mot-cai-kinh-vien-vong-co-kha-nang-cuu-song-nhan-loai-201905020844174.chn': 30,
#  'http://cafebiz.vn/dua-sieu-thi-vao-hoat-dong-sai-quy-dinh-mediamart-bi-phat-80-trieu-dong-201905021736502.chn': 31,
#  'http://cafebiz.vn/loi-cuoi-cua-ty-phu-bi-ung-thu-su-dac-y-cong-danh-loi-loc-doi-voi-nguoi-sap-chet-tro-nen-vo-nghia-chi-co-sinh-menh-la-gia-tri-nhung-mat-roi-khong-tim-lai-duoc-201905081717222.chn': 32,
#  'http://cafebiz.vn/co-phieu-uber-rot-manh-trong-phien-chao-san-201905111924049.chn': 33,
#  'http://cafebiz.vn/khoa-hoc-chung-minh-hut-thuoc-la-khien-cau-nho-bi-rut-201905131346003.chn': 34,
#  'http://cafebiz.vn/amazon-trien-khai-may-dong-hang-nhanh-gap-5-nguoi-2-may-thay-duoc-24-nhan-su-hoan-von-sau-2-nam-gia-1-trieu-do-may-201905141342017.chn': 35,
#  'http://cafebiz.vn/manh-van-chu-viet-tam-thu-gui-nhan-vien-huawei-201905141352222.chn': 36,
#  'http://cafebiz.vn/ai-thuoc-3-con-giap-sinh-vao-3-nam-nay-la-gioi-kiem-tien-nhat-lam-viec-gi-cung-vuong-tai-20-nam-toi-cua-cai-tai-san-du-da-201905141541087.chn': 37,
#  'http://cafebiz.vn/6-con-giap-phat-len-dip-cuoi-nam-tai-khoan-tang-so-nha-dep-xe-sang-cho-doi-201905141713552.chn': 38,
#  'http://cafebiz.vn/ngo-nghinh-va-dang-yeu-voi-nhung-buc-tranh-duoc-ve-len-cac-hop-dien-cu-ky-o-pho-co-ha-noi-tac-gia-la-mot-guong-mat-la-ma-quen-201905160853219.chn': 39,
#  'http://cafebiz.vn/ban-khao-khat-duoc-sang-song-tai-nhat-ban-u-nen-kinh-te-thu-3-the-gioi-nay-dang-doi-an-day-201905171516465.chn': 40,
#  'http://cafebiz.vn/bai-hoc-rut-ra-o-tuoi-30-khien-cuoc-song-toi-thay-doi-khong-ngo-do-la-noi-ban-khoan-ma-nhieu-nguoi-di-het-cuoc-doi-van-chua-the-thau-het-201905180818475.chn': 41,
#  'http://cafebiz.vn/tu-ram-thang-4-co-3-con-giap-duoc-than-tai-go-cua-tien-bac-cua-cai-nhan-len-gap-boi-201905181031305.chn': 42,
#  'http://cafebiz.vn/di-du-hoc-khong-suong-toi-da-vuot-qua-tram-cam-nhu-the-nao-mot-minh-tu-lap-ngoai-ngu-kem-nhung-khong-dam-ke-voi-gia-dinh-201905181119015.chn': 43,
#  'http://cafebiz.vn/that-bai-doi-nguoi-thu-dang-so-nhat-chinh-la-cai-gi-ban-cung-khong-lam-va-tu-an-ui-minh-rang-song-cuoc-doi-binh-thuong-moi-la-dang-quy-nhat-201905200938465.chn': 44,
#  'http://cafebiz.vn/chuyen-gia-giai-dap-ve-can-benh-gan-400-trieu-nguoi-mac-gay-tu-vong-chi-dung-sau-ung-thu-201905201643135.chn': 45,
#  'http://cafebiz.vn/viet-nam-chua-co-tu-duy-chien-luoc-trong-xay-dung-thuong-hieu-quoc-gia-201905210816365.chn': 46,
#  'http://cafebiz.vn/da-nang-se-cong-bo-500-lo-dat-cho-doanh-nghiep-nguoi-dan-dau-gia-cong-khai-201905211344095.chn': 47,
#  'http://cafebiz.vn/tung-qua-nhung-ngay-do-lua-nhu-thay-park-da-den-luc-bau-duc-cong-phuong-ghi-ban-thang-vang-201905220831155.chn': 48,
#  'http://cafebiz.vn/nha-dau-tu-bat-dong-san-van-theo-tam-ly-dam-dong-201905220951035.chn': 49,
#  'http://cafebiz.vn/kho-khan-vuot-qua-duoc-chinh-la-mon-qua-cho-nguoi-truong-thanh-neu-mac-ket-lai-no-se-la-cai-ho-khong-day-bop-nghet-ban-201905221502455.chn': 50,
#  'http://cafebiz.vn/bitcoin-lien-tuc-that-bai-o-nguong-8500-usd-tai-sao-201905221634265.chn': 51,
#  'http://cafebiz.vn/di-sau-grab-trong-mang-goi-xe-nhung-be-group-lai-sap-chay-truoc-doi-thu-trong-mang-tai-chinh-201905221747395.chn': 52,
#  'http://cafebiz.vn/dung-iphone-tai-trung-quoc-gio-day-la-viec-lam-dang-xau-ho-201905231000175.chn': 53,
#  'http://cafebiz.vn/bien-doi-khi-hau-co-the-khien-nuoc-bien-dang-them-hon-2m-201905231025115.chn': 54,
#  'http://cafebiz.vn/hsbc-len-tieng-ve-viec-khach-hang-phan-anh-lai-suat-hon-cho-vay-nang-lai-201905240836108.chn': 55,
#  'http://cafebiz.vn/danh-y-chia-se-cach-chua-viem-mui-viem-da-di-ung-nguoi-co-benh-co-the-tham-khao-201905241604473.chn': 56,
#  'http://cafebiz.vn/neu-chan-cong-viec-van-phong-go-bo-thoi-gian-lieu-ban-co-du-can-dam-de-bo-tat-ca-ma-di-nhu-cap-doi-travel-blogger-nay-201905251127427.chn': 57,
#  'http://cafebiz.vn/truoc-pegatron-bo-viet-nam-sang-indonesia-mot-dai-gia-khac-cung-du-kien-du-an-ty-do-o-viet-nam-roi-chuyen-huong-dau-tu-sang-an-do-201905251540499.chn': 58,
#  'http://cafebiz.vn/chuyen-gia-pwc-khi-trung-quoc-hat-hoi-thi-cac-thi-truong-moi-noi-cung-so-mui-nhung-viet-nam-van-la-mot-diem-sang-cho-cac-nha-dau-tu-201905260805596.chn': 59,
#  'http://cafebiz.vn/thanh-nien-24-tuoi-vao-vien-cap-cuu-sau-khi-tap-the-duc-bac-si-canh-bao-loi-nhieu-nguoi-mac-201905260822002.chn': 60,
#  'http://cafebiz.vn/nhung-co-gai-dap-mat-xay-lai-o-trung-quoc-doi-sang-trang-nho-dien-mao-moi-den-noi-xem-bac-si-tham-my-la-cha-me-thu-2-201905261305446.chn': 61,
#  'http://cafebiz.vn/lieu-phap-trao-doi-chat-chung-ta-co-the-an-kieng-de-bo-doi-te-bao-ung-thu-duoc-hay-khong-201905270841081.chn': 62,
#  'http://cafebiz.vn/kieu-cha-me-may-xen-co-luon-loai-bo-tro-ngai-cho-con-muc-dich-khong-xau-nhung-he-luy-khon-luong-201905271552088.chn': 63,
#  'http://cafebiz.vn/cuoc-doi-12-con-giap-se-sang-trang-moi-giau-co-noi-tiep-giau-co-chi-khi-gap-quy-nhan-la-nhung-nguoi-nay-201905291431218.chn': 64,
#  'http://cafebiz.vn/dieu-gi-xay-ra-khi-dong-nhan-dan-te-xuong-duoi-muc-7-nhan-dan-te-usd-201905300852435.chn': 65,
#  'http://cafebiz.vn/nha-su-hoang-nhat-doi-nguoi-muon-thuan-loi-hay-lay-nhat-lam-chu-nghia-ket-giao-lay-diec-de-don-nhan-loi-vu-cao-lay-nghiem-giao-huan-ban-than-201905300955027.chn': 66,
#  'http://cafebiz.vn/vinfast-se-ban-giao-xe-fadil-vao-giua-thang-6-201905311729259.chn': 67,
#  'http://cafebiz.vn/man-kho-nhuc-ke-trong-nuoc-co-cuoi-doi-cua-luu-bi-vi-da-nhin-thau-da-tam-khong-minh-201905311730224.chn': 68,
#  'http://cafebiz.vn/quay-lai-cong-viec-sau-nghi-le-thang-tien-trong-su-nghiep-hay-khong-hon-nhau-o-5-diem-nay-2019032309050007.chn': 69,
#  'http://cafebiz.vn/vat-va-trong-cay-co-ngay-hai-trai-khong-ep-ban-than-mot-lan-ban-lam-sao-co-the-biet-minh-co-the-no-luc-toi-dau-2019032910521946.chn': 70,
#  'http://cafebiz.vn/toi-la-nguoi-nua-huong-ngoai-nua-huong-noi-ben-ngoai-gia-la-tuoi-cuoi-voi-moi-nguoi-nhung-luon-thay-co-doc-ngot-ngat-ben-trong-2019032916270832.chn': 71,
#  'http://cafebiz.vn/hoc-gi-thi-hoc-the-he-gen-y-khong-the-bo-qua-ky-nang-nay-neu-muon-vuot-qua-thanh-tuu-cua-gen-x-va-baby-boomers-2019033016252282.chn': 72,
#  'http://cafebiz.vn/thu-nay-con-quan-trong-hon-iq-phai-so-huu-no-ban-moi-co-the-thanh-cong-2019033100523071.chn': 73,
#  'http://cafebiz.vn/albert-einstein-da-tung-duoc-chinh-phu-israel-moi-ve-lam-tong-thong-the-nhung-ong-mot-muc-khuoc-tu-2019040108562171.chn': 74,
#  'http://cafebiz.vn/dieu-thuong-xay-ra-nhung-hiem-nhan-vien-de-y-da-di-lam-muon-dung-choc-sep-noi-dien-2019040110050682.chn': 75,
#  'http://cafebiz.vn/bac-si-benh-vien-viet-duc-noi-ve-benh-nhan-ung-thu-dang-dieu-tri-con-so-giat-minh-anh-chi-a-han-che-tra-sua-tran-chau-an-uong-via-he-la-tot-nhat-2019040110152046.chn': 76,
#  'http://cafebiz.vn/vi-sao-hang-loat-ong-lon-bat-dong-san-ram-ro-vao-thanh-pho-mong-cai-2019040110221407.chn': 77,
#  'http://cafebiz.vn/chinh-truong-anh-hon-loan-trong-song-gio-brexit-2019040115140871.chn': 78,
#  'http://cafebiz.vn/y-nghia-cua-reiwa-nien-hieu-trieu-dai-moi-o-nhat-ban-2019040115350071.chn': 79,
#  'http://cafebiz.vn/bat-tay-voi-an-phat-san-xuat-linh-kien-nhua-o-to-vinfast-da-chi-bao-nhieu-tien-2019040116333957.chn': 80,
#  'http://cafebiz.vn/mot-dai-gia-ban-le-viet-dung-la-chuoi-thay-nilon-boc-thuc-pham-free-nuoc-lanh-tra-da-cho-khach-hang-nhung-ngay-nang-nong-2019040116381257.chn': 81,
#  'http://cafebiz.vn/nguon-goc-va-y-nghia-nien-hieu-moi-reiwa-lenh-hoa-cua-nhat-ban-2019040116562371.chn': 82,
#  'http://cafebiz.vn/thoi-cua-mo-hinh-banh-da-lam-hai-long-khach-hang-ho-se-quay-tro-lai-mua-tiep-nguoc-lai-ho-se-ngan-can-nhung-khach-khac-den-voi-ban-2019040117224171.chn': 83,
#  'http://cafebiz.vn/ngay-3-4-chinh-thuc-khoi-cong-cao-toc-van-don-mong-cai-hon-11-nghin-ty-2019040208352432.chn': 84,
#  'http://cafebiz.vn/thanh-tra-toan-dien-hoat-dong-quan-ly-dat-dai-tai-khu-lien-hop-the-thao-my-dinh-2019040209525107.chn': 85,
#  'http://cafebiz.vn/chang-co-cong-viec-nao-khong-the-dua-ban-thanh-trieu-phu-tru-khi-chinh-ban-mac-ket-trong-3-loi-suy-nghi-ngheo-kho-thuong-gap-tu-bo-di-truoc-khi-qua-muon-2019040210094757.chn': 86,
#  'http://cafebiz.vn/cuoc-chien-cua-cac-san-tmdt-shopee-vua-thu-phi-nguoi-ban-tiki-tuyen-bo-mien-phi-2-nam-2019040210184421.chn': 87,
#  'http://cafebiz.vn/may-chu-go-viet-bi-loi-tam-thoi-tai-tphcm-2019040210205796.chn': 88,
#  'http://cafebiz.vn/game-thu-kiem-ceo-ty-phu-cua-startup-esports-22-ty-usd-cay-pubg-xuyen-dem-dieu-hanh-cong-ty-nhu-choi-game-chien-luoc-va-sieu-ghet-tim-cook-vi-ong-ay-day-som-hon-toi-2019040211344082.chn': 89,
#  'http://cafebiz.vn/shopee-lazada-thu-phi-nguoi-ban-tiki-lai-mien-phi-han-2-nam-cuoc-tuyen-chien-khoc-liet-dang-dien-ra-tren-thi-truong-tmdt-2019040211580832.chn': 90,
#  'http://cafebiz.vn/mien-phi-tum-lum-ceo-chui-thang-doi-thu-la-ngu-ngoc-noi-nhuc-cua-nha-mang-tu-vuc-pha-san-t-mobile-da-thay-doi-ca-nganh-vien-thong-my-voi-vi-ceo-dien-ro-2019040211582246.chn': 91,
#  'http://cafebiz.vn/lo-dien-dai-gia-bat-dong-san-muon-dau-tu-du-an-khu-do-thi-1700-ty-tai-mong-cai-2019040213422521.chn': 92,
#  'http://cafebiz.vn/hoc-gia-canh-bao-trung-quoc-doi-mat-suy-thoai-te-nhat-neu-khong-som-ket-thuc-chien-tranh-thuong-mai-voi-my-2019040214175682.chn': 93,
#  'http://cafebiz.vn/trung-quoc-ban-chuot-bien-doi-gen-voi-gia-17000-usd-cap-mo-ra-thi-truong-ty-usd-moi-2019040214311232.chn': 94,
#  'http://cafebiz.vn/gia-cuoc-5g-tai-han-quoc-11-trieu-thang-duoc-8gb-25-trieu-thang-duoc-300gb-khong-co-goi-khong-gioi-han-2019040216493432.chn': 95,
#  'http://cafebiz.vn/ha-noi-mung-ro-sieu-thi-lon-goi-rau-bang-la-chuoi-thay-tui-nilon-2019040217263982.chn': 96,
#  'http://cafebiz.vn/muon-tre-tu-lap-tu-be-hay-hoc-cach-cung-ran-nhu-cha-me-nhat-cho-con-di-da-ngoai-bi-mat-de-con-tu-don-dep-chang-can-den-lao-cong-2019040217290546.chn': 97,
#  'http://cafebiz.vn/giau-co-bac-nhat-nhieu-ti-phu-my-van-chi-o-nhung-ngoi-nha-re-tien-2019040219010082.chn': 98,
#  'http://cafebiz.vn/du-khach-trung-quoc-bat-ngo-giam-manh-2019040219045657.chn': 99,
#  'http://cafebiz.vn/hotgirl-an-chay-sup-do-hinh-tuong-sau-nhieu-nam-gay-dung-chi-vi-mot-dia-thuc-an-dung-la-mieng-an-la-mieng-toi-tan-2019040310214032.chn': 100,
#  'http://cafebiz.vn/vi-sao-thi-truong-bds-tai-nhung-vung-dat-moi-noi-nhan-duoc-su-quan-tam-lon-cua-nha-dau-tu-2019040310381021.chn': 101,
#  'http://cafebiz.vn/ceo-huawei-apple-khong-canh-tranh-noi-phan-cung-voi-chung-toi-nen-moi-phai-chuyen-sang-dich-vu-2019040313284646.chn': 102,
#  'http://cafebiz.vn/kenh-youtube-cua-kha-banh-chinh-thuc-bi-xoa-2019040313432457.chn': 103,
#  'http://cafebiz.vn/van-chuyen-trai-phep-40000-usd-bi-tich-thu-35000-usd-dong-phat-1-ti-dong-2019040314360921.chn': 104,
#  'http://cafebiz.vn/luu-bi-co-ngu-ho-tuong-tao-thao-co-ngu-tu-tuong-ton-quyen-co-gi-trong-tay-ma-tao-duoc-the-chan-vac-lay-lung-thoi-tam-quoc-2019040316365921.chn': 105,
#  'http://cafebiz.vn/khong-phai-brexit-dai-dich-tram-nam-co-don-moi-dang-la-hiem-hoa-lan-rong-tu-anh-ra-toan-the-gioi-2019040316380882.chn': 106,
#  'http://cafebiz.vn/thoi-quen-viet-email-ngan-gon-den-ngo-ngang-cua-jeff-bezos-chi-voi-2-3-tu-cung-khien-nguoi-thi-toat-mo-hoi-nguoi-thi-ne-vai-phan-2019040317195632.chn': 107,
#  'http://cafebiz.vn/van-chuyen-trai-phep-40000-usd-bi-tich-thu-35000-usd-dong-phat-1-ti-dong-2019040318583521.chn': 108,
#  'http://cafebiz.vn/het-dien-lai-xang-tang-gia-soc-dang-sau-do-la-cau-chuyen-gi-2019040319045921.chn': 109,
#  'http://cafebiz.vn/ve-nuoc-ban-tom-giong-cong-ty-cua-viet-kieu-uc-duoc-dinh-gia-toi-330-trieu-usd-cao-hon-ca-vua-tom-minh-phu-2019040408421607.chn': 110,
#  'http://cafebiz.vn/vien-ksnd-toi-cao-khang-dinh-xu-nghiem-vu-ong-nguyen-huu-linh-sam-so-be-gai-trong-thang-may-2019040408530296.chn': 111,
#  'http://cafebiz.vn/vien-ksnd-toi-cao-khang-dinh-xu-nghiem-vu-ong-nguyen-huu-linh-sam-so-be-gai-trong-thang-may-2019040409082071.chn': 112,
#  'http://cafebiz.vn/mo-dau-lon-nhat-arab-saudi-dang-can-kiet-nhanh-hon-bao-gio-het-2019040409160046.chn': 113,
#  'http://cafebiz.vn/infographic-5-ong-lon-nganh-cong-nghe-kiem-hang-ty-usd-tu-dau-2019040409203757.chn': 114,
#  'http://cafebiz.vn/lan-song-dau-tu-vao-bat-dong-san-khu-cong-nghiep-2019040409321871.chn': 115,
#  'http://cafebiz.vn/clip-sai-gon-nong-buc-va-day-la-su-chenh-lech-nhiet-do-giua-duong-nhieu-cay-xanh-va-duong-khong-mot-bong-cay-2019040411241496.chn': 116,
#  'http://cafebiz.vn/can-bo-nhan-vien-vib-techcombank-acb-chuan-bi-nhan-thuong-lon-2019040413382432.chn': 117,
#  'http://cafebiz.vn/mot-truong-dai-hoc-o-viet-nam-lot-top-200-truong-anh-huong-nhat-den-su-phat-trien-kinh-te-xa-hoi-cua-the-gioi-2019040413500796.chn': 118,
#  'http://cafebiz.vn/hai-cong-ty-song-bac-rot-gan-7-ty-usd-vao-singapore-2019040413520082.chn': 119,
#  'http://cafebiz.vn/tin-vui-cho-dan-nghien-du-lich-gia-ve-may-bay-vietnam-airlines-duoc-du-bao-giam-5-vi-dieu-nay-2019040415193446.chn': 120,
#  'http://cafebiz.vn/the-economist-lam-the-nao-de-chuan-bi-cho-khung-hoang-kinh-te-toan-cau-sap-toi-2019040419221982.chn': 121,
#  'http://cafebiz.vn/la-co-dong-lon-cua-apple-warren-buffett-van-dung-dien-thoai-samsung-2019040420341482.chn': 122,
#  'http://cafebiz.vn/cua-hang-ky-la-o-australia-noi-moi-hang-hoa-duoc-ban-deu-phai-gui-toi-trung-quoc-2019040508081157.chn': 123,
#  'http://cafebiz.vn/bo-cong-thuong-muon-thanh-lap-uy-ban-canh-tranh-quoc-gia-tang-them-nhieu-bien-che-2019040508334357.chn': 124,
#  'http://cafebiz.vn/dung-ep-chi-ban-bun-bo-len-giam-doc-cong-ty-2019040508444107.chn': 125,
#  'http://cafebiz.vn/103-trieu-dong-cho-doi-dep-khet-let-va-chiec-xe-dap-vuot-103-km-cua-cau-be-son-la-su-tu-te-cua-nhung-nguoi-xa-la-2019040509061432.chn': 126,
#  'http://cafebiz.vn/tien-si-viet-tai-anh-du-hoc-ve-nuoc-that-nghiep-la-do-ban-than-kem-coi-nghi-minh-du-gioi-sao-khong-tu-mo-cong-ty-2019040509090307.chn': 127,
#  'http://cafebiz.vn/chung-ta-co-the-song-bat-tu-nho-thay-the-lien-tuc-cac-noi-tang-trong-co-the-minh-hay-khong-2019040510081946.chn': 128,
#  'http://cafebiz.vn/hai-hoc-sinh-cap-3-che-tao-thanh-cong-may-thu-gom-nong-san-tu-dong-2019040513372621.chn': 129,
#  'http://cafebiz.vn/ty-phu-thai-lan-bo-tui-1-ty-usd-sau-khi-dat-cuoc-vao-dien-mat-troi-o-viet-nam-2019040513410446.chn': 130,
#  'http://cafebiz.vn/khong-can-xep-hang-tai-cay-atm-hay-ra-ngan-hang-de-chuyen-rut-tien-nhung-ung-dung-nay-dang-tiet-kiem-thoi-gian-chet-cho-nguoi-dung-tien-mat-toan-the-gioi-2019040516045382.chn': 131,
#  'http://cafebiz.vn/sau-spacex-facebook-toi-luot-amazon-muon-phong-hang-nghin-ve-tinh-len-quy-dao-de-phu-song-intenet-toi-moi-mien-trai-dat-2019040516563057.chn': 132,
#  'http://cafebiz.vn/khoi-nghiep-co-nen-bo-het-trung-vao-1-gio-2019040608274107.chn': 133,
#  'http://cafebiz.vn/con-dau-pho-di-bo-nguyen-hue-hang-rong-bua-vay-ghe-nhua-tran-lan-loi-di-cho-khach-ngoi-an-uong-2019040608274957.chn': 134,
#  'http://cafebiz.vn/ty-phu-tony-robbins-khang-dinh-chi-co-tien-ma-thieu-di-dieu-quan-trong-nay-thi-khong-du-de-ban-cam-thay-hanh-phuc-va-giau-co-thuc-su-2019040611230546.chn': 135,
#  'http://cafebiz.vn/nam-thanh-nien-roi-loan-tam-than-vi-sap-cuoi-vo-2019040612434971.chn': 136,
#  'http://cafebiz.vn/bds-nghi-duong-la-san-choi-rong-nhung-khong-phai-ai-cung-tham-gia-duoc-2019040613510696.chn': 137,
#  'http://cafebiz.vn/bloomberg-thong-bao-dau-tu-vao-viet-nam-ong-trum-nang-luong-thai-lan-giau-them-1-ty-usd-2019040614150482.chn': 138,
#  'http://cafebiz.vn/tang-gia-xang-dau-tac-dong-nhu-the-nao-toi-lam-phat-2019040614165146.chn': 139,
#  'http://cafebiz.vn/chang-trai-sai-gon-kiem-41-ty-dong-qua-mang-kha-banh-chua-la-gi-2019040618290232.chn': 140,
#  'http://cafebiz.vn/hon-18000-chai-tuong-ot-chinsu-bi-thu-hoi-o-nhat-ban-vi-chua-hoa-chat-cam-2019040620212621.chn': 141,
#  'http://cafebiz.vn/khanh-hoa-xem-xet-lai-quy-hoach-do-thi-de-dua-tp-nha-trang-len-do-thi-loai-1-vao-nam-2020-2019040707550882.chn': 142,
#  'http://cafebiz.vn/tphcm-keu-goi-nhieu-tap-doan-da-quoc-gia-tham-gia-phat-trien-sieu-du-an-khu-do-thi-thong-minh-tai-khu-dong-2019040717184307.chn': 143,
#  'http://cafebiz.vn/nganh-cong-nghiep-nao-se-tao-ra-ty-phu-voi-tai-san-nghin-ty-usd-trong-tuong-lai-2019040718120396.chn': 144,
#  'http://cafebiz.vn/cang-truong-thanh-cang-tham-thia-khoc-chang-phai-do-yeu-duoi-ma-la-khong-so-hai-truoc-cam-xuc-cua-minh-2019040720142432.chn': 145,
#  'http://cafebiz.vn/tu-truong-hop-nguoi-dan-ong-bi-dot-quy-mat-bac-si-chi-ra-dau-hieu-dot-quy-mat-can-chu-y-2019040720232982.chn': 146,
#  'http://cafebiz.vn/fastgo-de-lo-thong-tin-email-cua-hang-tram-tai-xe-singapore-2019040722163821.chn': 147,
#  'http://cafebiz.vn/ikigai-dieu-gi-khien-ban-roi-giuong-vao-moi-sang-2019040801264421.chn': 148,
#  'http://cafebiz.vn/nikkei-nha-buon-cho-truyen-thong-viet-nam-canh-tranh-quyet-liet-voi-sieu-thi-cua-hang-tien-loi-2019040809023657.chn': 149,
#  'http://cafebiz.vn/tuyen-bo-giai-nghe-streamer-pewpew-nhan-gui-neu-ban-con-tre-hay-song-sao-toi-30-tuoi-nghi-lai-va-mim-cuoi-2019040809280821.chn': 150,
#  'http://cafebiz.vn/nhieu-truong-dai-hoc-viet-nam-chay-dua-khen-thuong-ca-nhan-co-nghien-cuu-xuat-sac-de-giu-nhan-tai-nhung-vi-sao-giang-vien-van-tho-o-2019040812471857.chn': 151,
#  'http://cafebiz.vn/da-tim-ra-cach-luu-tru-nang-luong-tai-tao-bang-khi-metan-khong-con-lo-tinh-trang-thua-dien-nhung-khong-co-cho-luu-2019040813345757.chn': 152,
#  'http://cafebiz.vn/khong-tien-khong-quan-he-nhung-van-muon-thanh-cong-chi-can-kien-tri-lam-3-viec-duoi-day-moi-thu-se-luon-nam-trong-tam-kiem-soat-cua-ban-2019040814273232.chn': 153,
#  'http://cafebiz.vn/benh-mo-mau-cao-khong-tru-mot-ai-muon-khong-co-benh-thi-nen-chu-y-7-dieu-quan-trong-2019040815464982.chn': 154,
#  'http://cafebiz.vn/ong-nguyen-nam-long-duoc-bo-nhiem-tong-giam-doc-vnpt-vinaphone-2019040816584523.chn': 155,
#  'http://cafebiz.vn/korean-air-gia-toc-tai-tieng-gan-lien-voi-loat-be-boi-bao-hanh-lam-quyen-va-uc-hiep-ke-yeu-gay-rung-dong-han-quoc-2019040908252725.chn': 156,
#  'http://cafebiz.vn/dang-sau-nhom-mau-hiem-duoc-vi-nhu-vang-la-moi-nguy-hiem-khong-phai-ai-cung-biet-2019040908381975.chn': 157,
#  'http://cafebiz.vn/vi-sao-apple-de-dang-bi-hai-sinh-vien-trung-quoc-qua-mat-bao-hanh-ca-iphone-hang-fake-2019040909083225.chn': 158,
#  'http://cafebiz.vn/mr-ferrari-tu-tay-choi-sieu-xe-toi-cha-do-dau-cua-ngua-chom-tai-nhat-ban-2019040910021225.chn': 159,
#  'http://cafebiz.vn/co-nen-rot-tien-vao-nha-dat-nhung-dia-phuong-sap-duoc-len-doi-thanh-pho-2019040910392725.chn': 160,
#  'http://cafebiz.vn/pewdiepie-giau-toi-co-nao-day-chinh-la-cau-tra-loi-2019040911004408.chn': 161,
#  'http://cafebiz.vn/huawei-san-sang-de-cung-cap-chip-modem-5g-cho-iphone-sau-khi-apple-bi-samsung-va-qualcomm-tu-choi-2019040913325577.chn': 162,
#  'http://cafebiz.vn/muon-bo-hoc-de-lam-streamer-pewpew-khuyen-dung-moi-ngay-lam-viec-12-tieng-kho-hon-di-hoc-khi-ngu-chi-so-dot-tu-2019040915132857.chn': 163,
#  'http://cafebiz.vn/doan-xe-trung-nguyen-phong-vun-vut-noi-duoi-vuot-den-do-cong-an-moi-cac-tai-xe-len-lam-viec-2019040915544207.chn': 164,
#  'http://cafebiz.vn/di-het-con-duong-ta-moi-thay-dau-la-dich-den-leo-het-ngon-nui-ta-moi-hieu-hai-chu-gian-nan-lay-thai-do-quyet-dinh-van-menh-2019040917052407.chn': 165,
#  'http://cafebiz.vn/viet-nam-quyet-tam-nghien-cuu-san-xuat-vac-xin-phong-dich-ta-lon-2019040918575143.chn': 166,
#  'http://cafebiz.vn/cach-nguoi-nhat-chien-dau-voi-nan-tu-sat-no-luc-cuu-vot-mot-cong-dong-bi-xa-hoi-ruong-bo-2019040919034418.chn': 167,
#  'http://cafebiz.vn/chuyen-gia-dh-yale-va-oxford-day-la-thu-lam-ban-hanh-phuc-hon-ca-viec-co-nhieu-tien-2019040919065029.chn': 168,
#  'http://cafebiz.vn/tphcm-thi-truong-van-phong-tiep-tuc-khan-hiem-nguon-cung-trong-quy-1-2019-2019041008580115.chn': 169,
#  'http://cafebiz.vn/doa-danh-thue-eu-ong-trump-phat-di-thong-diep-dang-so-voi-the-gioi-chien-tranh-thuong-mai-chua-ket-thuc-2019041010434151.chn': 170,
#  'http://cafebiz.vn/nong-dai-gia-phuc-xo-nguoi-deo-vang-nhieu-nhat-viet-nam-vua-bi-bat-2019041010492151.chn': 171,
#  'http://cafebiz.vn/muc-tieu-huy-dong-duoc-10-ty-usd-su-kien-ipo-cua-uber-vao-top-10-thuong-vu-ipo-lon-nhat-moi-thoi-dai-2019041011205887.chn': 172,
#  'http://cafebiz.vn/xet-xu-vu-an-gai-ma-tuy-tong-nguoi-yeu-vao-tu-toi-dua-1-ty-de-anh-ta-di-tu-khong-danh-dap-toi-nua-2019041014053417.chn': 173,
#  'http://cafebiz.vn/vpbank-noi-gi-khi-bi-to-vat-chanh-bo-vo-cho-thoi-viec-1000-nhan-vien-2019041014470442.chn': 174,
#  'http://cafebiz.vn/ba-nguyen-thi-nhu-loan-quoc-cuong-gia-lai-co-12-du-an-ach-tac-2019041015551292.chn': 175,
#  'http://cafebiz.vn/viet-cho-ban-tre-hay-di-du-lich-muon-check-in-thanh-cong-thai-do-cua-ban-se-quyet-dinh-chat-luong-ky-nghi-cua-ban-2019041016120367.chn': 176,
#  'http://cafebiz.vn/2-vo-chong-trung-nguyen-cung-khang-cao-ba-le-hoang-diep-thao-bat-ngo-muon-doan-tu-ong-dang-le-nguyen-vu-muon-tang-ty-le-chia-tai-san-len-73-2019041019580628.chn': 177,
#  'http://cafebiz.vn/chum-anh-hang-nghin-nguoi-dan-chen-lan-vat-vo-cho-lay-so-thu-tu-xin-visa-5-nam-cua-han-quoc-2019041108404003.chn': 178,
#  'http://cafebiz.vn/bo-cua-phuc-xo-toi-cho-phuc-khong-biet-bao-nhieu-tien-roi-vong-vang-tai-san-gia-dinh-vet-het-dua-cho-con-2019041108434442.chn': 179,
#  'http://cafebiz.vn/apple-co-the-phat-hanh-den-5-chiec-iphone-trong-nam-nay-2019041108493203.chn': 180,
#  'http://cafebiz.vn/nhoi-them-toa-nha-18-tang-vao-khu-do-thi-trung-hoa-nhan-chinh-thu-tuong-yeu-cau-xu-ly-2019041108575892.chn': 181,
#  'http://cafebiz.vn/bang-chung-chi-diem-trai-dat-dang-o-giua-giai-doan-tuyet-chung-lan-thu-6-2019041110482453.chn': 182,
#  'http://cafebiz.vn/hanh-trinh-ve-phuong-dong-giai-ma-ve-coi-vo-hinh-va-moi-giao-hao-voi-vong-linh-nguoi-qua-co-cua-chuyen-gia-nghien-cuu-2019041111270567.chn': 183,
#  'http://cafebiz.vn/chuyen-gia-nhat-bi-ung-thu-tung-an-nhung-mon-nay-de-ho-tro-chua-benh-ban-co-the-tham-khao-2019041114554425.chn': 184,
#  'http://cafebiz.vn/facebook-messenger-bi-nhay-chu-loan-xa-tu-sang-chi-co-2-cach-tam-thoi-de-tranh-loi-2019041116033211.chn': 185,
#  'http://cafebiz.vn/pewdiepie-da-giup-flappy-bird-thanh-cong-nhu-the-nao-2019041117432508.chn': 186,
#  'http://cafebiz.vn/he-lo-cuoc-doi-thoai-nay-lua-giua-nu-hoang-anh-voi-chau-trai-harry-ve-meghan-khien-ba-bau-nay-cung-hong-hoang-tu-thi-bat-luc-2019041208493019.chn': 187,
#  'http://cafebiz.vn/cai-ket-dang-truoc-bao-1-sao-cach-chuc-cua-hang-truong-xuong-lam-nhan-vien-ve-sinh-chua-du-the-alley-hang-bai-da-tam-ngung-hoat-dong-khong-hen-ngay-tro-lai-2019041209492569.chn': 188,
#  'http://cafebiz.vn/phuc-xo-thua-nhan-20-kg-vang-deo-tren-nguoi-deu-la-vang-gia-2019041211010244.chn': 189,
#  'http://cafebiz.vn/day-la-walt-cu-to-yeu-menh-cua-iphone-chiec-dien-thoai-day-tham-vong-ma-apple-khong-the-tung-ra-thi-truong-2019041213413877.chn': 190,
#  'http://cafebiz.vn/instagram-bi-nguoi-dung-to-hien-thi-story-cua-nguoi-la-2019041216531227.chn': 191,
#  'http://cafebiz.vn/imf-canh-bao-70-nen-kinh-te-toan-cau-se-suy-giam-muc-toi-te-nhat-trong-8-nam-qua-2019041217252277.chn': 192,
#  'http://cafebiz.vn/ai-sinh-vao-nhung-ngay-am-lich-sau-co-so-menh-phu-phu-nhan-ca-doi-song-trong-nhung-lua-hau-van-binh-an-sung-suong-2019041217394574.chn': 193,
#  'http://cafebiz.vn/chu-tich-viettel-viettel-thanh-lap-cong-ty-an-ninh-mang-nhan-trach-nhiem-tro-thanh-la-chan-thep-tai-viet-nam-2019041220440454.chn': 194,
#  'http://cafebiz.vn/nhung-con-so-nay-co-dang-chung-minh-hien-thuc-ve-xu-huong-dong-von-trung-quoc-ao-at-dich-chuyen-sang-viet-nam-2019041308124812.chn': 195,
#  'http://cafebiz.vn/dan-ong-so-di-nham-duong-phu-nu-so-cuoi-nham-chong-con-nguoi-sau-50-tuoi-chi-so-tung-pham-5-sai-lam-sau-doc-moi-thay-tham-thia-2019041308432701.chn': 196,
#  'http://cafebiz.vn/hanh-trinh-cuoc-song-voi-nhung-dau-moc-ai-cung-phai-trai-qua-moi-chang-duong-mot-bai-hoc-nguoi-tich-luy-du-se-thanh-cong-ke-khong-ngo-ra-som-se-phai-tra-gia-2019041308533701.chn': 197,
#  'http://cafebiz.vn/qua-trinh-pha-huy-mot-dua-tre-luon-mieng-treu-dua-me-de-em-trai-cho-chau-ra-ria-hua-hen-cho-vui-nguoi-lon-vo-tinh-da-khien-con-tre-am-anh-ca-doi-2019041309582051.chn': 198,
#  'http://cafebiz.vn/diem-mat-11-startup-nhan-duoc-tien-tuoi-thoc-that-tu-shark-tank-viet-nam-mua-2-duy-co-mot-ca-map-suot-tu-mua-1-den-gio-van-chua-cong-bo-giai-ngan-dong-nao-2019041315075851.chn': 199,
#  'http://cafebiz.vn/anh-nhieu-tre-nho-lac-cha-me-hoang-so-giua-bien-nguoi-do-ve-le-hoi-den-hung-2019041315464712.chn': 200,
#  'http://cafebiz.vn/case-study-chuyen-that-bai-cua-startup-tieu-het-135-trieu-usd-trong-18-thang-2019041409434145.chn': 201,
#  'http://cafebiz.vn/tai-xe-chay-taxi-cong-nghe-phoi-bay-thuc-te-khac-nghiet-ngay-kiem-1-trieu-dong-nhung-chi-phi-len-toi-13-trieu-ai-vao-sau-deu-an-may-ca-2019041508214903.chn': 202,
#  'http://cafebiz.vn/7-trieu-chung-khong-dau-co-the-la-dau-hieu-som-cua-ung-thu-kham-som-co-the-cuu-song-ban-2019041512140128.chn': 203,
#  'http://cafebiz.vn/3-con-giap-troi-khong-so-dat-khong-so-ai-co-ban-doi-tuoi-nay-phai-het-suc-than-trong-2019041512182617.chn': 204,
#  'http://cafebiz.vn/6-bi-quyet-giup-tre-nhat-ban-co-suc-khoe-top-dau-the-gioi-cha-me-viet-nam-nen-tham-khao-2019041512312978.chn': 205,
#  'http://cafebiz.vn/dong-cua-dung-3-ngay-tranh-bao-1-sao-nay-the-alley-da-tro-lai-ma-khong-biet-co-loi-hai-hon-khong-2019041513154742.chn': 206,
#  'http://cafebiz.vn/het-danh-gia-cong-dan-theo-doi-tu-nhan-gio-day-trung-quoc-con-giam-sat-ca-cong-nhan-ve-sinh-bang-vong-deo-gps-2019041513201728.chn': 207,
#  'http://cafebiz.vn/troi-sinh-3-con-giap-mang-menh-phu-quy-khong-the-choi-cai-nua-cuoi-nam-2019-tai-van-bung-no-bat-ngo-su-nghiep-tinh-duyen-deu-my-man-2019041517035003.chn': 208,
#  'http://cafebiz.vn/that-bai-ton-thuong-deu-khong-tranh-khoi-trong-doi-nhung-cach-ban-doi-mat-moi-la-dieu-gia-tri-nhat-neu-cuoc-song-la-mot-bai-kiem-tra-muc-tieu-song-chinh-la-cong-thuc-giai-2019041519252792.chn': 209,
#  'http://cafebiz.vn/nghe-si-le-binh-toi-cau-xin-troi-dat-cho-minh-du-suc-lam-not-3-viec-cuoi-cung-truoc-khi-ra-di-2019041519442703.chn': 210,
#  'http://cafebiz.vn/gs-phan-van-truong-noi-khong-tin-lam-vao-cong-nghe-cao-trong-nong-nghiep-cac-chuyen-gia-khac-phan-bien-ra-sao-2019041600291339.chn': 211,
#  'http://cafebiz.vn/chay-du-doi-bao-phu-nha-tho-duc-ba-paris-dinh-thap-850-nam-tuoi-sup-do-2019041608150839.chn': 212,
#  'http://cafebiz.vn/grab-khong-can-thiet-bat-xe-taxi-cong-nghe-phai-deo-mao-2019041617021875.chn': 213,
#  'http://cafebiz.vn/cuoc-choi-tat-tay-cua-coca-cola-buoc-chan-vao-dia-hat-cua-vinamilk-th-chon-viet-nam-la-thi-truong-dau-tien-tren-toan-the-gioi-ra-mat-san-pham-sua-2019041617340736.chn': 214,
#  'http://cafebiz.vn/hon-1-nua-dan-so-mac-benh-kho-noi-nay-dau-la-dau-hieu-ban-phai-toi-vien-ngay-2019041617402736.chn': 215,
#  'http://cafebiz.vn/ong-trum-nganh-hang-xa-xi-lvmh-bernard-arnault-tuyen-bo-se-quyen-gop-200-trieu-euro-de-tai-xay-dung-nha-tho-duc-ba-2019041618534561.chn': 216,
#  'http://cafebiz.vn/gioi-tre-trung-quoc-dang-phat-cuong-voi-dich-vu-lam-gia-su-giau-co-mat-chi-20000-dong-de-song-ao-voi-do-hieu-sieu-xe-2019041708242177.chn': 217,
#  'http://cafebiz.vn/apple-va-qualcomm-bat-ngo-dinh-chien-cham-dut-kien-tung-tren-toan-cau-2019041708344902.chn': 218,
#  'http://cafebiz.vn/33-tuoi-thu-nhap-ca-nghe-tay-trai-lan-tay-phai-von-ven-chi-10-trieu-3-loai-suy-nghi-khien-doi-toi-bet-bat-2019041709324227.chn': 219,
#  'http://cafebiz.vn/tro-thanh-trieu-phu-sau-khi-that-cu-tong-thong-my-2019041713382024.chn': 220,
#  'http://cafebiz.vn/khong-phai-my-day-moi-la-que-huong-cua-cac-ngan-hang-lon-nhat-the-gioi-2019041713404049.chn': 221,
#  'http://cafebiz.vn/tu-ma-qr-khong-lo-den-phat-23-trieu-vi-nhai-keo-cao-su-day-la-14-thu-chi-chau-a-moi-co-2019041717204585.chn': 222,
#  'http://cafebiz.vn/muc-so-thi-trang-trai-nuoi-hang-trieu-con-gian-lam-moi-nhau-2019041808321535.chn': 223,
#  'http://cafebiz.vn/phu-huynh-cua-21-thi-sinh-duoc-nang-diem-o-son-la-giu-nhieu-chuc-vu-quan-trong-cua-tinh-2019041808555735.chn': 224,
#  'http://cafebiz.vn/thi-sinh-duoc-nang-25-diem-la-con-can-bo-nao-o-son-la-2019041811043235.chn': 225,
#  'http://cafebiz.vn/vi-sao-ong-trump-co-the-chap-nhan-mot-thoa-thuan-thuong-mai-toi-voi-trung-quoc-2019041813453446.chn': 226,
#  'http://cafebiz.vn/chuyen-gia-pham-chi-lan-boc-bach-nhung-noi-lo-voi-buc-tranh-kinh-te-tu-nhan-viet-nam-2019041814314146.chn': 227,
#  'http://cafebiz.vn/bi-quyet-khoi-nghiep-thanh-cong-cua-cac-nu-cuong-nhan-phan-1-2019041814573221.chn': 228,
#  'http://cafebiz.vn/uniqlo-khong-theo-xu-huong-khong-chay-trao-luu-nhung-cung-du-thay-doi-ca-nen-thoi-trang-the-gioi-2019041815254621.chn': 229,
#  'http://cafebiz.vn/airasia-cham-dut-hop-tac-voi-thien-minh-group-nhung-tuyen-bo-khong-tu-bo-thi-truong-viet-nam-2019041819222054.chn': 230,
#  'http://cafebiz.vn/bi-tu-choi-visa-my-8-lan-eric-yuan-van-tro-thanh-ty-phu-cong-nghe-tren-dat-my-2019041909361923.chn': 231,
#  'http://cafebiz.vn/chuyen-mang-giu-so-viettel-tiep-tuc-dan-dau-ve-so-thue-bao-dang-ky-chuyen-den-2019041912300873.chn': 232,
#  'http://cafebiz.vn/con-ca-map-apple-da-bat-dau-lan-la-vao-be-mau-cua-samsung-va-xiaomi-2019041913313245.chn': 233,
#  'http://cafebiz.vn/amazon-dong-cua-o-trung-quoc-day-la-ly-do-tai-sao-ga-khong-lo-guc-nga-o-thi-truong-13-ty-dan-2019041913363095.chn': 234,
#  'http://cafebiz.vn/who-va-unicef-canh-bao-dich-soi-dang-thanh-khung-hoang-toan-cau-so-ca-mac-benh-tang-300-2019041913402809.chn': 235,
#  'http://cafebiz.vn/365-ngay-cat-luc-lam-viec-chi-den-khi-nghe-cuoc-goi-cuoc-goi-tu-nguoi-dong-nghiep-toi-moi-hieu-doi-nguoi-co-gang-khong-phai-de-cho-ban-than-2019041915434106.chn': 236,
#  'http://cafebiz.vn/choi-dua-quan-trong-the-nao-2019041917062356.chn': 237,
#  'http://cafebiz.vn/lam-duoc-4-dieu-nay-sep-noi-gi-nhan-vien-cung-nghe-theo-2019042008320125.chn': 238,
#  'http://cafebiz.vn/chinh-sach-that-chat-nhap-khau-tu-viet-nam-cua-trung-quoc-va-ly-do-co-the-an-chua-dang-sau-2019042011460175.chn': 239,
#  'http://cafebiz.vn/ke-ca-khi-khong-co-gi-trong-tay-ban-van-con-lai-mot-thu-quy-gia-cuoc-doi-cho-ban-ca-tram-ly-do-de-khoc-hay-cho-doi-thay-ban-co-ca-ngan-ly-do-de-cuoi-2019042011551261.chn': 240,
#  'http://cafebiz.vn/chap-nhan-ngay-lam-8-tieng-cuoi-thang-nhan-luong-nhung-chang-he-hanh-phuc-toi-nhan-ra-dieu-cay-dang-khien-nhieu-nguoi-cung-dang-mac-ket-co-chap-voi-su-lua-chon-sai-lam-ban-se-lang-phi-ca-mot-doi-2019042012010436.chn': 241,
#  'http://cafebiz.vn/ha-noi-thong-qua-du-thao-dieu-chinh-dia-gioi-hanh-chinh-3-quan-cau-giay-bac-tu-liem-nam-tu-liem-2019042016111786.chn': 242,
#  'http://cafebiz.vn/chuyen-gia-phan-tich-hang-khong-uc-phan-tich-ly-do-airasia-va-thien-minh-dung-hop-tac-2019042018250272.chn': 243,
#  'http://cafebiz.vn/vo-chong-ca-si-phu-le-bi-dieu-tra-vi-quang-cao-thuoc-khong-giay-phep-voi-tac-dung-tren-troi-2019042018545872.chn': 244,
#  'http://cafebiz.vn/khi-suc-sang-tao-dang-dan-can-kiet-apple-nen-hoc-hoi-microsoft-de-quay-lai-vi-the-xua-2019042108391319.chn': 245,
#  'http://cafebiz.vn/em-cua-vi-quyet-chien-qua-doi-va-chuyen-xe-cuoi-cung-dua-luc-ve-que-nha-gap-anh-trai-2019042108411269.chn': 246,
#  'http://cafebiz.vn/adele-va-chuyen-tinh-8-nam-vua-dut-doan-cu-ngo-chan-ai-cuoc-doi-cuoi-cung-van-phai-noi-loi-chia-tay-2019042109313155.chn': 247,
#  'http://cafebiz.vn/nang-nong-gay-gat-o-mien-bac-keo-dai-den-bao-gio-2019042109351355.chn': 248,
#  'http://cafebiz.vn/25-thuong-hieu-duoc-yeu-thich-nhat-tai-my-2019042120574974.chn': 249,
#  'http://cafebiz.vn/de-dam-phan-tang-luong-hay-thang-chuc-di-vao-long-sep-hay-nam-chac-3-buoc-don-gian-sau-2019042209141507.chn': 250,
#  'http://cafebiz.vn/bat-ngo-ve-than-the-cua-nu-thu-khoa-truong-dai-hoc-su-pham-ha-noi-duoc-nang-diem-2019042209314882.chn': 251,
#  'http://cafebiz.vn/cu-thay-nuoc-ngoai-khen-viet-nam-nhat-the-gioi-la-buon-2019042211033732.chn': 252,
#  'http://cafebiz.vn/doan-van-menh-qua-dang-di-5-dang-di-tieu-cuc-de-khien-cong-viec-xoi-hong-bong-khong-ban-be-xa-lanh-thanh-cong-kho-toi-2019042211463871.chn': 253,
#  'http://cafebiz.vn/mot-ty-phu-gui-tiet-kiem-20-trieu-usd-lay-lai-trao-giai-cho-cac-nha-khoa-hoc-viet-du-kien-gia-tri-len-toi-1-trieu-usd-giai-vao-nam-2087-2019042211524171.chn': 254,
#  'http://cafebiz.vn/sau-phuc-xo-lai-xuat-hien-nguoi-dan-ong-khoe-bo-trang-suc-vang-khung-luc-truoc-toi-nang-100kg-deo-vang-miet-gio-con-co-40kg-2019042214122468.chn': 255,
#  'http://cafebiz.vn/chuyen-la-anh-nong-dan-chan-lon-trung-quoc-kiem-3000-usd-thang-co-5-trieu-nguoi-theo-doi-nhung-khong-co-gi-lien-quan-den-loai-lon-2019042216350454.chn': 256,
#  'http://cafebiz.vn/doanh-thu-gan-5900-ty-dong-vinhomes-bao-lai-rong-toi-2540-ty-dong-2019042307154887.chn': 257,
#  'http://cafebiz.vn/gia-dau-vot-len-tren-65-usd-thung-khi-my-chan-iran-xuat-khau-dau-2019042308412312.chn': 258,
#  'http://cafebiz.vn/nha-mang-nhat-quyet-khong-cho-sim-so-dep-chuyen-mang-giu-so-2019042309503351.chn': 259,
#  'http://cafebiz.vn/sau-tran-chien-cuoi-cung-o-endgame-tuong-lai-doi-avengers-se-di-ve-dau-ngoai-vu-tru-marvel-2019042310113526.chn': 260,
#  'http://cafebiz.vn/richard-branson-vi-ty-phu-luon-dat-minh-trong-che-do-hanh-phuc-dung-lam-viec-de-song-ma-hay-song-de-tan-huong-cong-viec-2019042311455473.chn': 261,
#  'http://cafebiz.vn/tesla-chinh-thuc-tuyen-chien-voi-uber-lyft-va-ca-grab-sau-nay-du-tinh-trien-khai-1-trieu-xe-robo-taxi-trong-nam-toi-2019042313482773.chn': 262,
#  'http://cafebiz.vn/khi-make-up-ket-doi-cung-app-thu-ky-nghe-cua-gioi-streamer-bi-netizen-trung-goi-la-tro-phu-thuy-2019042313524123.chn': 263,
#  'http://cafebiz.vn/trai-xoai-viet-nam-o-vi-tri-nao-tren-the-gioi-2019042318455386.chn': 264,
#  'http://cafebiz.vn/apple-co-nguy-co-phai-boi-thuong-1-ty-usd-vi-cong-nghe-nhan-dang-khuon-mat-nhan-nham-1-sinh-vien-la-toi-pham-2019042318585536.chn': 265,
#  'http://cafebiz.vn/sep-xiaomi-khang-dinh-du-dang-tang-truong-manh-nhung-cong-ty-van-phai-hoc-hoi-nhieu-chien-luoc-cua-huawei-2019042408411105.chn': 266,
#  'http://cafebiz.vn/vua-dau-tu-cua-the-gioi-ong-trum-softbank-mat-trang-130-trieu-usd-vi-dau-tu-bitcoin-2019042408423766.chn': 267,
#  'http://cafebiz.vn/cuu-diep-vien-edward-snowden-giai-thich-vi-sao-tu-dung-cia-lai-lap-tai-khoan-instagram-2019042408483366.chn': 268,
#  'http://cafebiz.vn/cuoc-doi-bi-kich-cua-nha-sang-lap-hang-xe-chevrolet-lam-tho-co-khi-tai-chinh-cong-ty-minh-sang-lap-ra-di-trong-pha-san-va-lang-quen-2019042409365691.chn': 269,
#  'http://cafebiz.vn/vu-ty-phu-trung-quoc-bi-cao-buoc-hiep-dam-nguoi-bi-an-tung-clip-len-mang-xa-hoi-2019042410103616.chn': 270,
#  'http://cafebiz.vn/bi-hai-chuyen-dam-phan-kinh-doanh-nguoi-au-tay-co-the-uong-bia-va-dung-lien-tuc-tu-18-21h-roi-moi-ngoi-vao-ban-an-toi-2019042415040566.chn': 271,
#  'http://cafebiz.vn/gs-phan-van-truong-chi-ra-diem-luu-y-ve-van-hoa-am-thuc-cac-doanh-nhan-can-nho-khi-dam-phan-voi-doi-tac-trung-quoc-2019042415400441.chn': 272,
#  'http://cafebiz.vn/thaco-se-chi-hon-7200-ty-cho-nong-nghiep-nam-2019-mo-ban-hagl-myanmar-giai-doan-2-2019042416491705.chn': 273,
#  'http://cafebiz.vn/bo-xay-dung-de-xuat-hai-phuong-an-quan-ly-phi-bao-tri-chung-cu-2019042508361124.chn': 274,
#  'http://cafebiz.vn/dai-gia-an-ninh-mang-quyet-lot-mat-na-nguoi-sinh-ra-bitcoin-2019042508552874.chn': 275,
#  'http://cafebiz.vn/gia-dat-khap-noi-tang-cao-vay-dau-la-nguyen-nhan-dang-dot-nong-thi-truong-2019042509054924.chn': 276,
#  'http://cafebiz.vn/cong-ngo-mon-cua-dai-noi-hue-duoc-khoac-ao-moi-bang-cong-nghe-hoi-nuoc-nong-tra-lai-mau-sac-nhu-186-nam-truoc-2019042510351524.chn': 277,
#  'http://cafebiz.vn/8-tieng-tron-ven-bo-anh-day-cam-xuc-ve-cuoc-song-muu-sinh-hoi-ha-cua-nhung-cong-nhan-sai-gon-sau-gio-tan-ca-2019042510394549.chn': 278,
#  'http://cafebiz.vn/troi-nong-ngam-lai-chia-se-bat-ngo-cua-co-thu-tuong-ly-quang-dieu-bi-quyet-thanh-cong-cua-singapore-nam-o-chiec-may-dieu-hoa-2019042512060388.chn': 279,
#  'http://cafebiz.vn/samsung-sap-ra-dong-tien-ma-hoa-cua-rieng-minh-samsung-coin-2019042513445699.chn': 280,
#  'http://cafebiz.vn/quan-ly-20-tuoi-lam-sao-chinh-phuc-duoc-doi-ngu-nhan-vien-50-tuoi-xem-minh-la-tre-con-2019042514413163.chn': 281,
#  'http://cafebiz.vn/tan-binh-itelecom-chao-san-bang-goi-cuoc-sieu-re-nham-toi-15-trieu-cong-nhan-tai-cac-khu-cong-nghiep-2019042515260299.chn': 282,
#  'http://cafebiz.vn/chay-nha-tho-duc-ba-paris-cong-nhan-hut-thuoc-tai-cong-truong-2019042515511463.chn': 283,
#  'http://cafebiz.vn/san-luong-tieu-thu-phia-nam-tang-gap-doi-hoa-phat-bao-lai-sau-thue-1810-ty-dong-trong-quy-1-2019-2019042515541949.chn': 284,
#  'http://cafebiz.vn/sap-duoc-coi-troi-phan-khuc-condotel-hien-nay-ra-sao-2019042608371032.chn': 285,
#  'http://cafebiz.vn/cha-lap-di-chuc-tang-nha-cho-nguoi-giup-viec-va-la-thu-gui-con-gai-con-a-long-hieu-thao-cua-con-chi-dang-gia-1-xu-2019042610143143.chn': 286,
#  'http://cafebiz.vn/kho-khan-cung-chi-la-thu-thach-long-dung-cam-va-su-kien-tri-10-hanh-trang-chong-shock-nghich-canh-tot-nhat-can-mang-theo-2019042610463468.chn': 287,
#  'http://cafebiz.vn/ngoi-nha-7-tang-vua-o-vua-cho-thue-voi-nhung-khu-vuon-treo-rat-nen-tho-o-vung-tau-2019042616472115.chn': 288,
#  'http://cafebiz.vn/triet-pha-duong-day-danh-bac-voi-so-tien-cuoc-lon-gap-3-lan-so-voi-duong-day-o-phu-tho-2019042708414023.chn': 289,
#  'http://cafebiz.vn/hoi-con-1-cau-roi-nghe-con-tra-loi-ong-bo-tin-con-ca-doi-se-tranh-duoc-tai-hoa-2019042709060348.chn': 290,
#  'http://cafebiz.vn/co-thao-lui-gia-dat-da-nang-ha-nhiet-2019042709324848.chn': 291,
#  'http://cafebiz.vn/7-chieu-thuc-zara-da-ap-dung-de-dan-tinh-phai-dien-dao-vi-quan-ao-cua-ho-2019042709374623.chn': 292,
#  'http://cafebiz.vn/lich-su-nhat-ban-sang-trang-nhat-hoang-moi-trieu-dai-moi-2019042709412673.chn': 293,
#  'http://cafebiz.vn/ba-trum-shark-tank-hoi-anh-co-tinh-dau-tu-roi-nuot-luon-startup-va-day-la-cau-tra-loi-cua-shark-thuy-2019042715164245.chn': 294,
#  'http://cafebiz.vn/thoi-quen-nguy-hiem-nang-nong-vua-len-xe-da-bat-dieu-hoa-cuc-lanh-2019042715391959.chn': 295,
#  'http://cafebiz.vn/nga-ha-thuy-tau-ngam-lon-nhat-the-gioi-mang-theo-sieu-ngu-loi-poseidon-2019042718291984.chn': 296,
#  'http://cafebiz.vn/tracodi-va-chien-luoc-tap-trung-trong-phan-tan-nam-2019-2019042807295042.chn': 297,
#  'http://cafebiz.vn/mot-nguoi-co-dang-gia-de-ket-giao-hay-khong-chi-can-nhin-4-dieu-sau-la-du-tu-co-chi-kim-day-la-phep-thu-tot-nhat-cua-nhan-loai-2019042809233281.chn': 298,
#  'http://cafebiz.vn/mai-me-kiem-tien-chay-theo-cac-moi-quan-he-va-danh-roi-gia-dinh-that-buon-buoi-hop-mat-gia-dinh-gan-nhat-la-tren-giuong-benh-2019042809575506.chn': 299,
#  'http://cafebiz.vn/sa-pa-nhung-ngay-khat-kho-nhat-lich-su-duong-pho-oi-buc-khoi-bui-khach-san-e-am-vi-thieu-nuoc-sinh-hoat-2019042810302281.chn': 300,
#  'http://cafebiz.vn/de-tro-thanh-phien-ban-hoan-hao-nhat-cua-chinh-minh-day-la-5-dieu-ban-can-phai-ghi-nho-dieu-so-1-hay-tro-thanh-bac-thay-tam-tri-2019042811321867.chn': 301,
#  'http://cafebiz.vn/nha-ket-hop-giua-kien-truc-hien-dai-voi-vat-lieu-truyen-thong-2019042814460817.chn': 302,
#  'http://cafebiz.vn/end-game-duoi-goc-nhin-kinh-te-hoc-kinh-te-se-ra-sao-neu-mot-nua-nhan-loai-bi-xoa-so-2019042815445217.chn': 303,
#  'http://cafebiz.vn/yeu-chieu-vo-nhu-mark-zuckerberg-phat-minh-ra-chiec-hop-go-than-ky-giup-ba-xa-ngu-ngon-hon-dan-mang-ai-ai-cung-muon-mot-cai-nhu-the-2019042818384342.chn': 304,
#  'http://cafebiz.vn/giai-thich-van-de-hack-nao-nhat-khi-xem-endgame-thuyet-du-hanh-thoi-gian-marvel-da-dung-la-gi-2019042820114817.chn': 305,
#  'http://cafebiz.vn/con-duong-nhuom-mau-mo-hoi-va-nuoc-mat-cua-nu-ty-phu-da-mau-dau-tien-o-my-khong-quan-trong-ban-la-ai-hay-den-tu-dau-thanh-cong-luon-bat-dau-tu-ban-2019042911060764.chn': 306,
#  'http://cafebiz.vn/cam-dong-hinh-anh-cau-be-phu-me-thu-gom-rac-trong-nhung-ngay-nghi-le-me-khong-duoc-nghi-chau-lam-cho-me-do-met-2019042913013775.chn': 307,
#  'http://cafebiz.vn/50-tuoi-van-co-bo-nao-cua-thanh-nien-25-tuoi-neu-ngoi-thien-moi-ngay-2019043009552286.chn': 308,
#  'http://cafebiz.vn/30-tuoi-van-chua-tim-ra-dinh-huong-cua-cuoc-song-nhung-4-cau-noi-don-gian-da-danh-thuc-ban-linh-khon-ngoan-trong-toi-2019043012112786.chn': 309,
#  'http://cafebiz.vn/can-benh-ung-thu-tu-not-ruoi-di-can-cuc-nhanh-dau-hieu-khac-biet-can-kham-ngay-2019043014334161.chn': 310,
#  'http://cafebiz.vn/cuoc-doi-nay-chang-qua-la-mot-van-co-ta-khong-the-khong-choi-danh-sai-mot-nuoc-ban-se-mat-tat-ca-2019043020021597.chn': 311,
#  'http://cafebiz.vn/chuoi-chua-den-ky-thu-hoach-doanh-thu-trai-cay-hagl-xuong-thap-ky-luc-lo-lon-tu-hoat-dong-kinh-doanh-chinh-2019050109062288.chn': 312,
#  'http://cafebiz.vn/nghien-cuu-moi-dang-an-kieng-van-nen-an-nhieu-com-hon-mot-chut-tham-chi-no-con-giup-giam-tinh-trang-beo-phi-tren-toan-the-gioi-2019050121554707.chn': 313,
#  'http://cafebiz.vn/khi-con-sot-smartphone-ha-nhiet-day-la-thu-samsung-dat-cuoc-tuong-lai-2019050210190137.chn': 314,
#  'http://cafebiz.vn/habeco-mot-lan-choi-lon-lieu-co-tram-tro-2019050210330437.chn': 315,
#  'http://cafebiz.vn/grab-da-dau-tu-hon-100-trieu-usd-cho-thi-truong-viet-nam-2019050210593023.chn': 316,
#  'http://cafebiz.vn/8-sai-lam-nho-khong-sua-ngay-se-dan-toi-tuong-lai-bi-huy-hoai-luoi-bieng-khong-kien-nhan-chac-chan-se-hoi-tiec-muon-mang-2019050214082434.chn': 317,
#  'http://cafebiz.vn/san-bay-long-thanh-can-them-5-ty-usd-nua-de-tranh-thanh-oc-dao-2019050219192984.chn': 318,
#  'http://cafebiz.vn/google-toan-tinh-gi-voi-ung-dung-game-moi-stadia-theo-doi-cach-ban-choi-game-de-hieu-cach-suy-nghi-so-thich-khuynh-huong-chinh-tri-va-nhieu-thong-tin-mat-thiet-cua-ban-2019050300315417.chn': 319,
#  'http://cafebiz.vn/quy-dau-tu-bat-dong-san-vi-sao-van-kho-phat-trien-2019050308320742.chn': 320,
#  'http://cafebiz.vn/cuoc-chien-giua-cong-nghe-cu-va-moi-nha-sang-lap-xiaomi-vua-thua-cuoc-1-ty-te-2019050308423267.chn': 321,
#  'http://cafebiz.vn/hoang-tu-be-hisahito-nguoi-thua-ke-cuoi-cung-cua-hoang-gia-nhat-duoc-nuoi-day-mot-cach-khac-nguoi-nhung-dan-chung-lai-dong-tinh-ung-ho-2019050309540592.chn': 322,
#  'http://cafebiz.vn/khoi-nghiep-tu-hai-ban-tay-trang-day-la-cach-ty-phu-con-nha-ngheo-nay-tan-dung-tung-manh-vun-xung-quanh-de-lam-giau-2019050310263717.chn': 323,
#  'http://cafebiz.vn/grab-da-dot-hon-100-trieu-usd-o-thi-truong-viet-nam-va-gio-ho-muon-dau-tu-vao-cac-startup-nong-nghiep-2019050310514392.chn': 324,
#  'http://cafebiz.vn/bi-mat-dang-sau-vi-sep-thich-hop-hanh-cam-giac-lam-tron-bon-phan-lanh-dao-khi-chu-tri-mot-dan-con-ngoan-ngoi-chung-phong-hop-2019050310564267.chn': 325,
#  'http://cafebiz.vn/trung-quoc-chiem-toi-1-3-bang-sang-che-cong-nghe-5g-tren-toan-the-gioi-ngoi-khong-cung-hai-ra-tien-2019050313360839.chn': 326,
#  'http://cafebiz.vn/lam-video-du-lich-youtuber-vo-tinh-quay-lai-chiec-vali-nghi-chua-thi-the-nan-nhan-trong-vu-giet-nguoi-hang-loat-tren-dao-sip-2019050313415514.chn': 327,
#  'http://cafebiz.vn/horea-doanh-nghiep-bds-tu-nhan-ngay-cang-lon-manh-nhung-phai-duong-dau-voi-nhieu-thach-thuc-rui-ro-2019050314503022.chn': 328,
#  'http://cafebiz.vn/khong-phai-captain-america-hay-thor-day-moi-la-biet-doi-avengers-ngoai-doi-thuc-dang-bao-ve-the-gioi-khoi-cai-chet-duoi-con-mat-cua-ty-phu-bill-gates-2019050315415733.chn': 329,
#  'http://cafebiz.vn/huong-dan-su-dung-google-assistant-tieng-viet-tren-android-2019050316475597.chn': 330,
#  'http://cafebiz.vn/phuc-bao-doi-nguoi-ca-loi-nguoc-dong-ca-moi-song-nguoi-vuot-nghich-canh-moi-mong-thanh-cong-2019050316545747.chn': 331,
#  'http://cafebiz.vn/neu-so-huu-dac-diem-nay-tren-mat-ban-co-the-la-nguoi-nam-giu-vi-tri-quyen-luc-cao-2019050317001347.chn': 332,
#  'http://cafebiz.vn/day-chinh-xac-la-nhung-dieu-cac-chuyen-gia-giac-ngu-thuc-hien-khi-tran-troc-khong-the-chop-mat-vao-ban-dem-chia-khoa-giup-ban-yen-giac-la-dieu-cuc-ky-de-thuc-hien-2019050322545705.chn': 333,
#  'http://cafebiz.vn/tu-4-diem-nay-ban-co-the-nhin-ra-cuoc-song-rieng-tu-cua-mot-dan-ong-sach-se-hay-khong-2019050409463891.chn': 334,
#  'http://cafebiz.vn/thiet-ke-don-gian-nhung-ngoi-nha-1-tang-o-ha-noi-van-dep-nhu-biet-thu-nghi-duong-2019050410490966.chn': 335,
#  'http://cafebiz.vn/apple-bi-kien-vi-su-dung-vat-lieu-khong-dat-chuan-khien-iphone-7-bi-hong-2019050413353363.chn': 336,
#  'http://cafebiz.vn/ceo-microsoft-nhac-nho-nhan-vien-dung-an-may-di-vang-dat-gia-tri-thi-truong-1-nghin-ty-usd-cha-co-nghia-ly-gi-2019050413395049.chn': 337,
#  'http://cafebiz.vn/vua-ipo-von-hoa-cong-ty-thit-thuc-vat-tang-gap-gan-3-lan-2019050413452388.chn': 338,
#  'http://cafebiz.vn/quy-dau-tu-cong-nghe-100-ty-usd-cua-softbank-co-the-sap-ipo-2019050413472249.chn': 339,
#  'http://cafebiz.vn/vtc-to-dien-luc-cat-cap-lam-hang-loat-dich-vu-noi-dung-so-bi-gian-doan-2019050415031124.chn': 340,
#  'http://cafebiz.vn/bo-cong-thuong-hua-se-cai-cach-bieu-gia-dien-bac-thang-2019050415550424.chn': 341,
#  'http://cafebiz.vn/su-that-tu-benh-nhan-7-nam-dieu-tri-ung-thu-rat-nhieu-nguoi-benh-ung-thu-tu-giet-nhau-2019050417004349.chn': 342,
#  'http://cafebiz.vn/tai-sao-bo-cong-thuong-muon-dong-dau-mat-thong-tin-gia-dien-xang-dau-2019050508070707.chn': 343,
# ...
#  'http://cafebiz.vn/thoi-buoi-nao-roi-con-viet-thu-tay-thoi-cua-tinh-yeu-nhung-van-vuong-va-doi-loi-khong-dam-noi-20190405083425585.chn': 889,
#  'http://cafebiz.vn/ty-phu-vung-tien-mua-my-nhan-lam-nguoi-tinh-cuoi-doi-lanh-trai-dang-chet-trong-ngheo-kho-20190405083936398.chn': 890,
#  'http://cafebiz.vn/bo-lao-dong-ti-le-that-nghiep-o-nhom-co-trinh-do-dai-hoc-giam-20190405085315257.chn': 891,
#  'http://cafebiz.vn/thay-gi-qua-viec-youtube-dong-y-gia-han-thoi-gian-cham-dut-chsa-voi-yeah1-20190405085738945.chn': 892,
#  'http://cafebiz.vn/dung-cat-luc-lam-viec-de-co-mot-ngoi-mo-dep-cho-thuong-de-o-khong-co-ngan-hang-nguoi-khon-ngoan-hay-hoc-cach-song-gioi-huong-thu-va-biet-kiem-tien-20190405090239195.chn': 893,
#  'http://cafebiz.vn/toan-canh-buc-tranh-thi-truong-dia-oc-tphcm-quy-dau-nam-2019-dat-nen-duoc-du-bao-tiep-tuc-la-kenh-dau-tu-hang-dau-20190405090806367.chn': 894,
#  'http://cafebiz.vn/tranh-cai-viec-dan-mang-keu-goi-check-in-truoc-nha-cuu-vien-pho-vks-sam-so-be-gai-20190405091540101.chn': 895,
#  'http://cafebiz.vn/nguoi-dan-ong-bi-dam-khi-nhac-nho-thieu-nien-vuot-den-do-da-tu-vong-20190405092612132.chn': 896,
#  'http://cafebiz.vn/nguoi-phu-nu-co-muc-luong-cao-nhat-viet-nam-la-ai-20190405093339898.chn': 897,
#  'http://cafebiz.vn/sau-vu-ly-hon-dat-do-nhat-the-gioi-vo-chong-ty-phu-amazon-van-danh-cho-nhau-nhung-loi-co-canh-het-tinh-con-nghia-la-day-20190405093441289.chn': 898,
#  'http://cafebiz.vn/2-cach-giup-ban-thang-chuc-nhanh-nhat-con-duong-toi-dinh-cao-hoa-ra-khong-he-kho-20190405093901054.chn': 899,
#  'http://cafebiz.vn/ty-phu-jeff-bezos-biet-on-vo-cu-vi-dong-y-voi-ty-le-co-phieu-7525-va-nhuong-lai-quyen-bo-phieu-tai-amazon-blue-origin-20190405094653164.chn': 900,
#  'http://cafebiz.vn/chuyen-truyen-ngoi-o-son-kova-khong-phai-con-ca-chang-phai-con-trai-canh-tay-thuong-mai-cua-tap-doan-duoc-giao-vao-tay-nguoi-chau-ngoai-va-day-la-ly-do-20190405100030101.chn': 901,
#  'http://cafebiz.vn/sep-cong-ty-moi-gioi-ke-chuyen-mua-dat-nen-moi-gio-mot-gia-va-dua-canh-bao-20190405100239414.chn': 902,
#  'http://cafebiz.vn/vien-cong-nghe-massachusetts-cua-my-quyet-dinh-cat-dut-quan-he-voi-huawei-va-zte-20190405100430617.chn': 903,
#  'http://cafebiz.vn/hai-thanh-nien-trung-quoc-dung-iphone-gia-lua-apple-gan-1-trieu-do-20190405100616945.chn': 904,
#  'http://cafebiz.vn/boc-tran-cuoc-song-gioi-tai-phiet-sieu-giau-showbiz-chau-a-quy-tac-nguoi-thuong-khong-hieu-duoc-on-ao-nhu-cung-dau-20190405105732289.chn': 905,
#  'http://cafebiz.vn/chan-dung-du-hoc-sinh-anh-nghi-viec-o-quy-dau-tu-top-10-the-gioi-voi-thu-nhap-gan-4-ty-dong-nam-ve-viet-nam-khoi-nghiep-dat-cuoc-vao-blockchain-20190405111936632.chn': 906,
#  'http://cafebiz.vn/khong-co-gan-thu-thach-dung-mo-mong-thanh-cong-dieu-quan-trong-nhat-ban-da-doi-mat-voi-kho-khan-mot-cach-tich-cuc-chua-20190405113007742.chn': 907,
#  'http://cafebiz.vn/khong-rieng-viet-nam-du-hoc-sinh-cung-dang-tro-thanh-lao-dong-mat-gia-tai-trung-quoc-20190405114733242.chn': 908,
#  'http://cafebiz.vn/ong-hut-than-thien-voi-moi-truong-tu-doanh-nghiep-viet-thu-hut-su-chu-y-cua-bao-singapore-20190405122843742.chn': 909,
#  'http://cafebiz.vn/nghien-cuu-cua-dai-hoc-tai-anh-ngui-mui-trung-tien-cua-nguoi-yeu-co-the-khien-ban-song-lau-hon-20190405123447445.chn': 910,
#  'http://cafebiz.vn/cong-viec-mo-uoc-cua-bat-ky-ai-du-lich-va-an-uong-mien-phi-con-duoc-tra-66-nghin-usd-mot-nam-20190405123918539.chn': 911,
#  'http://cafebiz.vn/cam-xe-may-tren-duong-nguyen-trai-le-van-luong-moi-chi-la-nghien-cuu-20190405131822585.chn': 912,
#  'http://cafebiz.vn/coder-trung-quoc-tuyen-bo-danh-bai-elon-musk-va-tesla-bang-thuc-luc-chu-khong-phai-di-an-cap-cong-nghe-20190405133138585.chn': 913,
#  'http://cafebiz.vn/di-ban-ga-ran-voi-muc-luong-beo-bot-nhung-chua-mot-ngay-toi-hoi-tiec-danh-doi-mo-hoi-toi-nhan-lai-5-bai-hoc-dat-gia-bien-minh-thanh-trieu-phu-usd-sau-nay-20190405133435195.chn': 914,
#  'http://cafebiz.vn/vi-sao-my-tung-dan-dau-the-gioi-ve-cong-nghe-vien-thong-ma-nay-lai-khong-co-cong-ty-nao-lam-duoc-5g-tam-co-huawei-20190405133451664.chn': 915,
#  'http://cafebiz.vn/khoan-phai-thu-hon-10000-ty-dong-cua-hoa-binh-co-dang-lo-ngai-20190405133935867.chn': 916,
#  'http://cafebiz.vn/hang-chuc-nu-nhan-vien-microsoft-to-bi-quay-roi-tinh-duc-moi-goi-ngoi-len-dui-nam-dong-nghiep-20190405134307335.chn': 917,
#  'http://cafebiz.vn/samsung-canh-bao-loi-nhuan-quy-1-sut-60-vi-gia-con-chip-giam-20190405134451382.chn': 918,
#  'http://cafebiz.vn/hon-chuc-ngan-hang-da-day-lai-suat-huy-dong-len-tren-8-nam-20190405135304085.chn': 919,
#  'http://cafebiz.vn/doanh-nghiep-vua-va-nho-viet-nam-lap-cap-khi-chuyen-doi-so-20190405141551851.chn': 920,
#  'http://cafebiz.vn/nha-dau-tu-bds-dang-do-tien-vao-dau-trong-nhung-thang-dau-nam-20190405142541257.chn': 921,
#  'http://cafebiz.vn/may-den-bua-vay-tesla-elon-musk-mat-hon-1-ty-usd-chi-trong-vong-2-phut-ngan-ngui-va-hau-toa-vi-va-mieng-20190405143729789.chn': 922,
#  'http://cafebiz.vn/phap-tai-tro-hon-11-ty-dong-cho-du-an-cho-dau-moi-quoc-te-nong-san-gia-lam-20190405143932632.chn': 923,
#  'http://cafebiz.vn/ceo-boeing-thua-nhan-loi-phan-mem-trong-hai-vu-tai-nan-may-bay-737-max-20190405144218367.chn': 924,
#  'http://cafebiz.vn/nu-du-khach-mac-ket-o-paris-da-tro-ve-viet-nam-sau-109-ngay-bi-cam-xuat-canh-khoi-phap-20190405144505664.chn': 925,
#  'http://cafebiz.vn/nguyen-vien-pho-vksnd-da-nang-thua-nhan-hon-be-gai-nhung-khai-khong-co-y-do-dam-o-20190405145635132.chn': 926,
#  'http://cafebiz.vn/tu-su-cua-sep-cac-ban-tre-cai-gi-cung-co-the-lam-duoc-neu-duoc-huong-dan-day-du-va-can-ke-nhung-thieu-tinh-ky-luat-long-trach-nhiem-va-tinh-thao-vat-20190405151833992.chn': 927,
#  'http://cafebiz.vn/ly-ky-chuyen-bql-chung-cu-cat-dien-de-nguyen-vien-truong-vksnd-da-nang-lo-dien-sau-khi-sam-so-be-gai-20190405153606679.chn': 928,
#  'http://cafebiz.vn/ca-si-jennifer-lopez-thuc-hien-thu-thach-10-ngay-khong-an-duong-carb-va-cai-ket-khien-nguoi-ta-phai-suy-nghi-20190405153704773.chn': 929,
#  'http://cafebiz.vn/bo-tai-chinh-noi-gi-ve-khoan-thue-chua-nop-tu-thu-nhap-khung-hon-400-trieu-dong-thang-cua-kha-banh-20190405155023101.chn': 930,
#  'http://cafebiz.vn/chieu-tro-ban-nem-tang-gia-de-roi-khuyen-mai-doi-ten-de-khoi-google-che-tinh-nang-la-de-khach-chi-them-tien-20190405155206898.chn': 931,
#  'http://cafebiz.vn/hai-nguoi-viet-duoc-de-cu-vinh-danh-tai-giai-thuong-vien-thong-chau-a-20190405160725132.chn': 932,
#  'http://cafebiz.vn/nhieu-bac-si-ty-phu-da-chet-nhieu-nguoi-tre-ban-mang-kiem-tien-bo-qua-suc-khoe-nghi-ngoi-khong-dung-cach-duong-den-nghia-dia-cua-ban-cang-ngan-lai-20190405161423539.chn': 933,
#  'http://cafebiz.vn/trung-quoc-han-che-san-xuat-xi-mang-gay-o-nhiem-viet-nam-bat-ngo-tan-dung-duoc-co-hoi-xuat-khau-nhung-vi-sao-nganh-vat-lieu-xay-dung-trong-nuoc-van-am-dam-20190405161818351.chn': 934,
#  'http://cafebiz.vn/vinfast-sap-vao-thi-truong-nga-20190405161857601.chn': 935,
#  'http://cafebiz.vn/buc-anh-dat-gia-cau-be-om-giay-moi-va-thong-diep-day-y-nghia-giup-nhieu-nguoi-biet-tran-trong-cuoc-song-hon-20190405162357351.chn': 936,
#  'http://cafebiz.vn/3-cap-con-giap-tuong-xung-lay-nhau-kho-am-em-gia-dao-luc-duc-cua-cai-tieu-tan-p1-20190405163127179.chn': 937,
#  'http://cafebiz.vn/tu-vi-tri-tan-binh-bamboo-airways-tro-thanh-hang-hang-khong-co-ty-le-bay-dung-gio-cao-nhat-va-day-la-ly-do-20190405163444085.chn': 938,
#  'http://cafebiz.vn/nguoi-dan-ong-bi-nhiem-trung-nao-suot-5-nam-chi-vi-so-suat-tu-cach-ve-sinh-tai-ai-cung-lam-nay-20190405164330023.chn': 939,
#  'http://cafebiz.vn/cung-1-canh-chia-tay-ty-phu-2-so-phan-nguoi-nhan-35-ty-usd-nguoi-phai-song-chung-voi-chong-cu-va-ban-gai-tai-san-chi-co-cai-tu-lanh-va-am-dun-nuoc-20190405164431617.chn': 940,
#  'http://cafebiz.vn/bo-truong-bo-tttt-nguyen-manh-hung-chi-ra-khuyet-tat-chet-nguoi-cua-cac-dn-lon-truoc-khi-sup-do-deu-trai-qua-6-buoc-nay-20190405165126585.chn': 941,
#  'http://cafebiz.vn/mot-nha-nghien-cuu-stanford-da-co-giai-phap-thay-the-cho-65-nam-com-ao-gao-tien-den-kiet-suc-cua-loai-nguoi-20190405170010226.chn': 942,
#  'http://cafebiz.vn/trung-quoc-nhay-viec-nhieu-qua-se-bi-tru-diem-tin-dung-xa-hoi-20190405170242632.chn': 943,
#  'http://cafebiz.vn/8000-ty-dong-giai-quyet-dut-diem-ngap-tai-trung-tam-tphcm-trong-nam-2019-20190405170249742.chn': 944,
#  'http://cafebiz.vn/apple-amazon-va-trung-quoc-la-3-nguyen-nhan-khien-loi-nhuan-samsung-giam-shock-60-20190405170429898.chn': 945,
#  'http://cafebiz.vn/hang-loat-dan-ong-do-xo-vao-twitter-vo-cu-ceo-amazon-buong-loi-choc-gheo-20190405170831289.chn': 946,
#  'http://cafebiz.vn/sau-2-vu-ly-hon-cua-2-ty-phu-trung-nguyen-va-amazon-khong-co-cuoc-chia-tay-qua-don-dau-neu-chut-tu-te-cho-nhau-van-con-20190405170959304.chn': 947,
#  'http://cafebiz.vn/google-facebook-amazon-se-de-doa-cac-ngan-hang-trong-luong-lai-20190405171159867.chn': 948,
#  'http://cafebiz.vn/can-ho-chung-cu-cai-tao-co-gia-thap-nhat-25-ty-dong-gay-choang-o-ha-noi-20190405171410882.chn': 949,
#  'http://cafebiz.vn/chi-o-viet-nam-khach-duoc-nha-mang-bao-cuoc-chuyen-vung-10-trieu-20190405171513476.chn': 950,
#  'http://cafebiz.vn/cai-tao-can-ho-gan-tram-tuoi-thanh-noi-o-hien-dai-nho-sac-vang-am-ap-20190405171612195.chn': 951,
#  'http://cafebiz.vn/hedwig-kohn-la-ai-ma-duoc-google-vinh-danh-hom-nay-20190405171651945.chn': 952,
#  'http://cafebiz.vn/de-cho-can-chet-nguoi-co-the-lanh-14-nam-tu-20190405172201414.chn': 953,
#  'http://cafebiz.vn/bo-truong-nguyen-manh-hung-mobile-money-se-giai-quyet-bai-toan-thanh-toan-khong-tien-mat-den-100-nguoi-dan-nhung-lai-thach-thuc-ngan-hang-20190405173003117.chn': 954,
#  'http://cafebiz.vn/ceo-ey-viet-nam-nhieu-chu-doanh-nghiep-co-tinh-gian-lan-gay-kho-cho-kiem-toan-20190405173150632.chn': 955,
#  'http://cafebiz.vn/diem-so-lang-nhang-cung-duoc-nhung-muon-ra-the-gioi-nhat-dinh-phai-hoc-day-la-cach-ty-phu-nguoi-my-giup-con-thanh-cong-20190405173652617.chn': 956,
#  'http://cafebiz.vn/ban-quyen-ngoai-hang-anh-lai-thuoc-ve-k-20190405201301101.chn': 957,
#  'http://cafebiz.vn/hang-loat-ong-lon-ban-le-dung-la-chuoi-thay-nilong-boc-thuc-pham-thu-tuong-viet-thu-khen-ngoi-20190405201441476.chn': 958,
#  'http://cafebiz.vn/vi-sao-bat-dong-san-phan-thiet-binh-thuan-tiep-tuc-sot-nong-20190405201550148.chn': 959,
#  'http://cafebiz.vn/ong-trinh-van-quyet-bamboo-airways-sap-bay-chuyen-quoc-te-dau-tien-diem-den-la-nhat-ban-20190405203900914.chn': 960,
#  'http://cafebiz.vn/so-du-lich-binh-thuan-vao-cuoc-xac-minh-resort-aroma-bi-to-lua-dao-de-doa-hanh-hung-khach-du-lich-20190405222732429.chn': 961,
#  'http://cafebiz.vn/phuong-phap-sieu-toc-giup-ban-hoc-kien-thuc-3-thang-chi-trong-vong-mot-tuan-20190406001943007.chn': 962,
#  'http://cafebiz.vn/mac-cho-cac-chuoi-ban-le-nuom-nuop-dong-cua-dai-gia-noi-that-sap-ve-viet-nam-ikea-van-tang-truong-deu-deu-nho-mot-khia-canh-dinh-cao-nay-20190406014654585.chn': 963,
#  'http://cafebiz.vn/khach-hang-khong-mua-san-pham-ho-mua-mot-phan-cau-chuyen-cac-thuong-hieu-ke-hay-hoc-cach-bien-chuyen-thanh-tien-nhu-cac-ong-lon-20190406015437179.chn': 964,
#  'http://cafebiz.vn/truoc-khi-tham-gia-cptpp-qua-thanh-long-sang-my-phai-mat-10-nam-20190406082936429.chn': 965,
#  'http://cafebiz.vn/voi-phat-minh-nay-canh-phong-vien-dang-co-nguy-co-that-nghiep-20190406083231351.chn': 966,
#  'http://cafebiz.vn/trung-quoc-bi-quyet-vuot-nhat-ban-va-chang-duong-buoc-ra-duoi-anh-mat-troi-tu-dong-tro-tan-suy-thoai-kinh-te-20190406083733273.chn': 967,
#  'http://cafebiz.vn/tai-sao-lam-phat-o-my-lai-thap-den-muc-dang-kinh-ngac-20190406083854539.chn': 968,
#  'http://cafebiz.vn/chuyen-ve-qua-bong-cuoi-xuat-hien-trong-nhung-bua-tiec-thuong-luu-tu-the-ky-19-de-lai-nhung-he-luy-kho-luong-20190406084439164.chn': 969,
#  'http://cafebiz.vn/trung-quoc-nhay-viec-nhieu-qua-se-bi-tru-diem-tin-dung-xa-hoi-20190406084621351.chn': 970,
#  'http://cafebiz.vn/nhieu-thue-bao-mobifone-bi-tru-het-tien-trong-tai-khoan-20190406085315304.chn': 971,
#  'http://cafebiz.vn/chu-villa-ban-nha-kieu-xo-so-bo-ra-1-trieu-ruoi-de-co-co-hoi-trung-biet-thu-hon-7-ty-xac-suat-1-6000-20190406085502601.chn': 972,
#  'http://cafebiz.vn/gdp-quy-i-thap-tang-truong-co-dau-hieu-cham-lai-20190406090906085.chn': 973,
#  'http://cafebiz.vn/chuyen-gia-khang-dinh-di-bo-la-bai-tap-tot-nhat-cho-ca-suc-khoe-va-tam-tri-moi-buoc-chan-la-lieu-thuoc-bo-giup-ban-hanh-phuc-hon-nang-dong-khoe-manh-hon-20190406091257679.chn': 974,
#  'http://cafebiz.vn/aroma-resort-bi-doi-ten-thanh-aroma-resort-lua-dao-khach-2-tr-va-nhan-hon-3000-danh-gia-1-sao-tren-google-sau-video-cua-khoa-pug-20190406093121554.chn': 975,
#  'http://cafebiz.vn/dat-nen-cac-tinh-lan-can-lot-vao-tam-ngam-cua-gioi-dau-tu-dia-oc-tphcm-lo-dien-nhung-diem-nong-20190406094335242.chn': 976,
#  'http://cafebiz.vn/chim-se-di-nang-tu-ke-me-game-den-thanh-nien-tau-xe-hop-tien-ty-o-tuoi-23-20190406101129648.chn': 977,
#  'http://cafebiz.vn/luu-tru-qua-han-o-singapore-mot-du-hoc-sinh-viet-nam-bi-phat-tu-va-danh-4-roi-20190406103937054.chn': 978,
#  'http://cafebiz.vn/loi-nhan-cua-vo-chong-ty-phu-bill-gates-toi-cac-con-ket-hon-dung-nguoi-con-quan-trong-hon-ca-viec-chon-truong-chon-nghe-hay-that-can-than-va-tinh-tao-20190406104349726.chn': 979,
#  'http://cafebiz.vn/kha-banh-da-bi-khoi-to-nhung-ngan-ban-mini-va-web-drama-giang-ho-nham-nhi-tren-youtube-ai-se-xu-li-20190406104403429.chn': 980,
#  'http://cafebiz.vn/ke-toan-dung-7-trieu-usd-tien-cong-ty-de-mua-iphone-ipad-ban-kiem-loi-20190406105055367.chn': 981,
#  'http://cafebiz.vn/cam-bien-van-tay-sieu-am-cua-galaxy-s10-da-bi-hack-nhu-the-nao-20190406105224914.chn': 982,
#  'http://cafebiz.vn/da-qua-roi-cai-thoi-nguoi-ta-mua-iphone-vi-camera-xin-20190406105425898.chn': 983,
#  'http://cafebiz.vn/tu-scandal-o-aroma-resort-nhin-lai-case-xu-ly-khon-ngoan-cua-mot-quan-ca-phe-bi-danh-gia-1-sao-tren-tripadvisor-khong-xoa-bai-dang-ma-khach-van-un-un-keo-den-20190406105444617.chn': 984,
#  'http://cafebiz.vn/tripadvisor-khoa-danh-gia-cua-aroma-resort-vi-cho-rang-cac-danh-gia-nay-khong-phan-anh-trai-nghiem-truc-tiep-20190406105602523.chn': 985,
#  'http://cafebiz.vn/moi-quyet-dinh-moi-hanh-dong-moi-lua-chon-se-dua-cuoc-doi-chung-ta-toi-mot-noi-khac-nhau-song-muon-den-duoc-dich-ban-nhat-dinh-phai-trai-qua-3-giai-doan-20190406111514351.chn': 986,
#  'http://cafebiz.vn/nu-luat-su-gao-coi-ben-canh-vua-cafe-trung-nguyen-trong-vu-ly-hon-nghin-ty-khi-than-chu-tim-den-toi-toi-luon-khuyen-nguoi-ta-suy-nghi-lai-20190406112103679.chn': 987,
#  'http://cafebiz.vn/bi-an-lang-mo-tan-thuy-hoang-phat-hien-moi-bac-bo-lam-tuong-vi-dai-suot-4-thap-ky-20190406112652867.chn': 988,
#  'http://cafebiz.vn/3-cap-con-giap-tuong-xung-lay-nhau-kho-am-em-gia-dao-luc-duc-cua-cai-tieu-tan-p2-20190406112948945.chn': 989,
#  'http://cafebiz.vn/khong-hen-ma-gap-ong-hoang-nam-tien-va-ong-dang-le-nguyen-vu-cung-noi-ve-1-hieu-ung-dac-biet-nhung-theo-2-nghia-khac-nhau-20190406113006695.chn': 990,
#  'http://cafebiz.vn/neu-ban-hay-bi-can-vao-luoi-khi-an-dung-bo-qua-3-yeu-to-nay-co-the-la-benh-nguy-hiem-20190406113620476.chn': 991,
#  'http://cafebiz.vn/ty-phu-tony-robbins-khang-dinh-chi-co-tien-ma-thieu-di-dieu-quan-trong-nay-thi-khong-du-de-ban-cam-thay-hanh-phuc-va-giau-co-thuc-su-20190406113953539.chn': 992,
#  'http://cafebiz.vn/chau-au-thong-qua-luat-cam-san-pham-nhua-su-dung-mot-lan-truoc-nam-2021-20190406114448929.chn': 993,
#  'http://cafebiz.vn/tuyen-bo-moi-gay-soc-nu-hoang-anh-cam-meghan-su-dung-do-trang-suc-cua-cong-nuong-diana-qua-co-nhung-kate-thi-duoc-phep-vi-ly-do-bat-ngo-nay-20190406114644835.chn': 994,
#  'http://cafebiz.vn/thu-truong-bo-khoa-hoc-cong-nghe-nhin-guong-sup-do-cua-nokia-yahoo-de-biet-rang-ngay-ca-khi-thanh-cong-chung-ta-van-can-doi-moi-moi-ngay-20190406115505804.chn': 995,
#  'http://cafebiz.vn/xau-la-mot-loai-benh-neu-khong-sao-cho-phau-thuat-tham-my-van-duoc-goi-la-benh-vien-20190406123342679.chn': 996,
#  'http://cafebiz.vn/vinfast-va-lg-chem-hop-tac-thanh-lap-lien-doanh-san-xuat-pin-20190406131329335.chn': 997,
#  'http://cafebiz.vn/chum-anh-cho-thay-van-hoa-lam-viec-khac-nghiet-nhat-the-gioi-cua-nhat-ban-20190406134001664.chn': 998,
#  'http://cafebiz.vn/xe-khach-bien-lao-dau-dau-xe-container-khien-tai-xe-gay-chan-quoc-lo-6-un-tac-keo-dai-20190406140250289.chn': 999,
#  'http://cafebiz.vn/mot-nha-nghien-cuu-stanford-da-co-giai-phap-thay-the-cho-65-nam-com-ao-gao-tien-den-kiet-suc-cua-loai-nguoi-20190406140630179.chn': 1000,
#  ...}

# %%
for key, valu in valid_articles_urls_to_ids_dict.items():    # for name, age in dictionary.iteritems():  (for Python 2.x)
    if valu == 1516:
        print(key)
# Out:
# http://cafebiz.vn/kinh-te-hoc-hon-nhan-vi-sao-phu-nu-it-duoc-yeu-hon-sau-khi-cuoi-20190413113206854.chn

# %%
len(valid_articles_urls_to_ids_dict)
# Out:
# 5194

# %%
len(articles_original_df['id'].unique())
# Out:
# 5194

# %%
articles_original_df['id'][0]
# Out:
# 20190416190831

# %% [markdown]
# ### Start Loading user interactions

# %%
df =  spark.read.parquet("/data/tungtv/jupytercode/data-log-news-parquet-thang45/")

# %%
# df.count()

# %%
# df.printSchema()

# %%
# df.select("url").distinct().count()

# %%
df.printSchema()
# Out:
# root
#  |-- full_url: string (nullable = true)
#  |-- dt: string (nullable = true)
#  |-- cookietime: string (nullable = true)
#  |-- browser_code: integer (nullable = true)
#  |-- browser_ver: string (nullable = true)
#  |-- os_code: integer (nullable = true)
#  |-- os_version: string (nullable = true)
#  |-- ip: long (nullable = true)
#  |-- loc_id: integer (nullable = true)
#  |-- domain: string (nullable = true)
#  |-- path: string (nullable = true)
#  |-- referer: string (nullable = true)
#  |-- guid: string (nullable = true)
#  |-- pageloadId: string (nullable = true)
#  |-- screen: string (nullable = true)
#  |-- d_guid: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- utm_source: string (nullable = true)
#  |-- utm_campaign: string (nullable = true)
#  |-- utm_medium: string (nullable = true)
#  |-- milis: long (nullable = true)
#  |-- tos: long (nullable = true)
#  |-- tor: long (nullable = true)
#  |-- top: long (nullable = true)
#  |-- scrollEnd: integer (nullable = true)
#  |-- pageLoadTime: long (nullable = true)
#  |-- lookUpTime: long (nullable = true)
#  |-- connectionTime: long (nullable = true)
#  |-- pageDownloadTime: long (nullable = true)
#  |-- responseTime: long (nullable = true)
#  |-- redirectTime: long (nullable = true)
#  |-- scrollCounter: long (nullable = true)
#  |-- mouseMoveCounter: long (nullable = true)
#  |-- touchMoveCounter: long (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- gender: integer (nullable = true)
#  |-- devCode: string (nullable = true)
#  |-- reqId: string (nullable = true)
#  |-- ads_code: integer (nullable = true)
#  |-- flash_ver: string (nullable = true)
#  |-- jre: string (nullable = true)
#  |-- sr: string (nullable = true)
#  |-- sc: integer (nullable = true)
#  |-- org_ip: string (nullable = true)
#  |-- d_guid_create: long (nullable = true)
#  |-- siteId: string (nullable = true)
#  |-- channelId: string (nullable = true)
#  |-- geo: integer (nullable = true)
#  |-- time: long (nullable = true)
#  |-- id: long (nullable = true)
#  |-- content: string (nullable = true)
#  |-- created_at_ts: long (nullable = true)
#  |-- teaser: string (nullable = true)
#  |-- keywords: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- url: string (nullable = true)
#  |-- category0: string (nullable = true)
#  |-- persons: string (nullable = true)
#  |-- locations: string (nullable = true)
#  |-- text_highlights: string (nullable = true)

# %%
# df.select("loc_id").where("loc_id = -1").count()

# %% [markdown]
# ### End Loading user interactions

# %%
interactions_df = df.select("full_url","dt","os_code","loc_id","path","referer"\
                            ,"guid","category","devCode","id","content","created_at_ts"\
                            ,"teaser","title","keywords","time","url", "top")

# %%
# interactions_df.select("url").show(1,False)

# %%
interactions_df.printSchema()
# Out:
# root
#  |-- full_url: string (nullable = true)
#  |-- dt: string (nullable = true)
#  |-- os_code: integer (nullable = true)
#  |-- loc_id: integer (nullable = true)
#  |-- path: string (nullable = true)
#  |-- referer: string (nullable = true)
#  |-- guid: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- devCode: string (nullable = true)
#  |-- id: long (nullable = true)
#  |-- content: string (nullable = true)
#  |-- created_at_ts: long (nullable = true)
#  |-- teaser: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- keywords: string (nullable = true)
#  |-- time: long (nullable = true)
#  |-- url: string (nullable = true)
#  |-- top: long (nullable = true)

# %%
# interactions_df.count()

# %%
# interactions_df.select("id","guid","url").show(10, False)

# %%
#Retrives article id from its cannonical URL (because sometimes article ids in interactions do no match with articles tables, but cannonical URL do)
def get_article_id_encoded_from_url(canonical_url):
    if canonical_url in valid_articles_urls_to_ids_dict:
        return valid_articles_urls_to_ids_dict[canonical_url]    
    return None

get_article_id_encoded_from_url_udf = F.udf(get_article_id_encoded_from_url, pyspark.sql.types.IntegerType())

# %%
#Filtering only interactions whose url/id is available in the articles table
interactions_article_id_encoded_df = interactions_df.withColumn('article_id', get_article_id_encoded_from_url_udf(interactions_df['url']))
interactions_filtered_df = interactions_article_id_encoded_df.filter(interactions_article_id_encoded_df['article_id'].isNull() == False).cache()

# %%
# interactions_filtered_df.select("article_id").distinct().count()

# %%
interactions_filtered_df.cache()
# Out:
# DataFrame[full_url: string, dt: string, os_code: int, loc_id: int, path: string, referer: string, guid: string, category: string, devCode: string, id: bigint, content: string, created_at_ts: bigint, teaser: string, title: string, keywords: string, time: bigint, url: string, top: bigint, article_id: int]

# %%
interactions_filtered_df.printSchema()
# Out:
# root
#  |-- full_url: string (nullable = true)
#  |-- dt: string (nullable = true)
#  |-- os_code: integer (nullable = true)
#  |-- loc_id: integer (nullable = true)
#  |-- path: string (nullable = true)
#  |-- referer: string (nullable = true)
#  |-- guid: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- devCode: string (nullable = true)
#  |-- id: long (nullable = true)
#  |-- content: string (nullable = true)
#  |-- created_at_ts: long (nullable = true)
#  |-- teaser: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- keywords: string (nullable = true)
#  |-- time: long (nullable = true)
#  |-- url: string (nullable = true)
#  |-- top: long (nullable = true)
#  |-- article_id: integer (nullable = true)

# %%
#Valid interactions
# interactions_filtered_df.count()

# %%
#Distinct items count
# interactions_filtered_df.select('id').distinct().count()

# %%
# modified
# interactions_filtered_df.type

# %%
def check_numm(df, name_col):
    return df.where(F.isnull(F.col(name_col))).count()

# %%
# check_numm(interactions_filtered_df, "time")

# %%
# check_numm(interactions_filtered_df, "id")

# %%
first_timestamp_ts = interactions_filtered_df.select('time').agg(F.min('time')).collect()[0][0] * 1000
first_timestamp_ts
# Out:
# 1554051934000

# %% [markdown]
# ### Analyzing elapsed time since publishing

# %%
# addition 
from pyspark.sql import functions as f
from pyspark.sql import types as t
interactions_filtered_df = interactions_filtered_df.withColumn("publish_ts"\
                            ,F.to_timestamp(interactions_filtered_df.created_at_ts.cast(dataType=t.TimestampType())))

# %%
interactions_filtered_df.printSchema()
# Out:
# root
#  |-- full_url: string (nullable = true)
#  |-- dt: string (nullable = true)
#  |-- os_code: integer (nullable = true)
#  |-- loc_id: integer (nullable = true)
#  |-- path: string (nullable = true)
#  |-- referer: string (nullable = true)
#  |-- guid: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- devCode: string (nullable = true)
#  |-- id: long (nullable = true)
#  |-- content: string (nullable = true)
#  |-- created_at_ts: long (nullable = true)
#  |-- teaser: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- keywords: string (nullable = true)
#  |-- time: long (nullable = true)
#  |-- url: string (nullable = true)
#  |-- top: long (nullable = true)
#  |-- article_id: integer (nullable = true)
#  |-- publish_ts: timestamp (nullable = true)

# %%
# interactions_filtered_df.select("publish_ts").show(1)
# Out:
# +-------------------+
# |         publish_ts|
# +-------------------+
# |2019-05-06 17:30:00|
# +-------------------+
# only showing top 1 row

# %%
interactions_filtered_df = interactions_filtered_df.withColumn("publish_ts", F.unix_timestamp(col("publish_ts"),'yyyy-MM-dd HH:mm:ss'))

# %%
interactions_filtered_df.printSchema()
# Out:
# root
#  |-- full_url: string (nullable = true)
#  |-- dt: string (nullable = true)
#  |-- os_code: integer (nullable = true)
#  |-- loc_id: integer (nullable = true)
#  |-- path: string (nullable = true)
#  |-- referer: string (nullable = true)
#  |-- guid: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- devCode: string (nullable = true)
#  |-- id: long (nullable = true)
#  |-- content: string (nullable = true)
#  |-- created_at_ts: long (nullable = true)
#  |-- teaser: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- keywords: string (nullable = true)
#  |-- time: long (nullable = true)
#  |-- url: string (nullable = true)
#  |-- top: long (nullable = true)
#  |-- article_id: integer (nullable = true)
#  |-- publish_ts: long (nullable = true)

# %%
#interactions_filtered_df.filter(interactions_filtered_df['time'].isNull()).count()
#0

# %% [raw]
# def get_timestamp_from_date_str(value):
#     if value is not None:
#         return int(datetime.datetime.strptime(value, 'yyyy-MM-dd HH:mm:ss').timestamp())
#     return None
#
# get_timestamp_from_date_str_udf = F.udf(get_timestamp_from_date_str, pyspark.sql.types.IntegerType())

# %%
# interactions_filtered_with_publish_ts_df = interactions_filtered_df.withColumn('publish_ts', get_timestamp_from_date_str_udf(interactions_filtered_df['publishtime']))
# interactions_filtered_with_publish_ts_df = interactions_filtered_with_publish_ts_df.withColumn('elapsed_min_since_published', ((F.col('time') - F.col('publish_ts')) / 60).cast(pyspark.sql.types.IntegerType()))

# %%
 interactions_filtered_with_publish_ts_df = interactions_filtered_df.withColumn('elapsed_min_since_published',\
                        ((F.col('time') - F.col('publish_ts')) / 60).cast(pyspark.sql.types.IntegerType()))

# %%
interactions_filtered_with_publish_ts_df.select('elapsed_min_since_published').show(4)
# Out:
# +---------------------------+
# |elapsed_min_since_published|
# +---------------------------+
# |                      24339|
# |                       9713|
# |                       9630|
# |                      10384|
# +---------------------------+
# only showing top 4 rows

# %%
#interactions_filtered_with_publish_ts_df.select('publishtime','publish_ts', 'time', 'elapsed_min_since_published').show(100)

# %%
# %%time
interactions_filtered_with_publish_ts_df.approxQuantile("elapsed_min_since_published", [0.10, 0.25, 0.50, 0.75, 0.90], 0.01)
#[49.0, 108.0, 334.0, 1020.0, 4611.0]
# Out:
# CPU times: user 11 ms, sys: 6.96 ms, total: 18 ms
# Wall time: 2.31 s
# [-366.0, -219.0, 504.0, 2186.0, 3710.0]

# %%
elapsed_min_since_published_df = interactions_filtered_with_publish_ts_df.select('elapsed_min_since_published').toPandas()
print(len(elapsed_min_since_published_df[pd.isnull(elapsed_min_since_published_df['elapsed_min_since_published'])]))
elapsed_min_since_published_df.describe()
# Out:
# 0
#        elapsed_min_since_published
# count                 6.409658e+06
# mean                  2.041369e+03
# std                   6.369303e+03
# min                  -5.420400e+04
# 25%                  -2.320000e+02
# 50%                   5.080000e+02
# 75%                   2.174000e+03
# max                   8.681400e+04

# %%
'''
elapsed_min_since_published
count	2.600818e+06
mean	6.438622e+04
std	5.051825e+05
min	-3.151590e+05
25%	9.400000e+01
50%	2.580000e+02
75%	8.370000e+02
max	8.608278e+06
'''
# Out:
# '\nelapsed_min_since_published\ncount\t2.600818e+06\nmean\t6.438622e+04\nstd\t5.051825e+05\nmin\t-3.151590e+05\n25%\t9.400000e+01\n50%\t2.580000e+02\n75%\t8.370000e+02\nmax\t8.608278e+06\n'

# %% [markdown]
# ### Analyzing clicks by article distribution

# %%
#clicks_by_article_count_df = interactions_filtered_df.groupBy('article_id').count()
#clicks_by_article_count_df.approxQuantile("count", [0.01, 0.10, 0.25, 0.50, 0.75, 0.90, 0.99], 0.01)
#[1.0, 1.0, 1.0, 1.0, 2.0, 6.0, 33581.0]

# %% [markdown]
# ### Processing categorical features

# %%
def get_categ_features_counts_dataframe(interactions_spark_df,column_name):
    df_pandas = interactions_spark_df.groupBy(column_name).count().toPandas().sort_values('count', ascending=False)
    return df_pandas

# %%
PAD_TOKEN = '<PAD>'
UNFREQ_TOKEN = '<UNF>'

def get_encoder_for_values(values):
    encoder_values = [PAD_TOKEN, UNFREQ_TOKEN] + values
    encoder_ids = list(range(len(encoder_values)))
    encoder_dict = dict(zip(encoder_values, encoder_ids))
    return encoder_dict

def get_categ_features_encoder_dict(counts_df, min_freq=100):
    freq_values = counts_df[counts_df['count'] >= 100][counts_df.columns[0]].values.tolist()
    encoder_dict = get_encoder_for_values(freq_values)
    return encoder_dict

def encode_cat_feature(value, encoder_dict):
    if value in encoder_dict:
        return encoder_dict[value]
    else:
        return encoder_dict[UNFREQ_TOKEN]

# %%
# countries_df = get_categ_features_counts_dataframe(interactions_filtered_df, 'country')
# len(countries_df)

# %%
# countries_encoder_dict = get_categ_features_encoder_dict(countries_df)
# len(countries_encoder_dict)

# %%
cities_df = get_categ_features_counts_dataframe(interactions_filtered_df, 'loc_id')
len(cities_df)
# Out:
# 223

# %%
cities_encoder_dict = get_categ_features_encoder_dict(cities_df)
len(cities_encoder_dict)
# Out:
# 135

# %%
# regions_df = get_categ_features_counts_dataframe(interactions_filtered_df, 'region')
# len(regions_df)

# %%
# regions_encoder_dict = get_categ_features_encoder_dict(regions_df)
# len(regions_encoder_dict)

# %%
# devices_df = get_categ_features_counts_dataframe(interactions_filtered_df, 'devCode')
# print(len(devices_df))
# devices_df

# %%
# devices_encoder_dict = get_categ_features_encoder_dict(devices_df)
# len(devices_encoder_dict)

# %%
os_df = get_categ_features_counts_dataframe(interactions_filtered_df, 'os_code')
print(len(os_df))
os_df
# Out:
# 7
#    os_code    count
# 5       10  5431067
# 6        2   436473
# 4        8   375549
# 3        9   106133
# 0        1    58091
# 2        5     2061
# 1        3      284

# %%
os_encoder_dict = get_categ_features_encoder_dict(os_df)
len(os_encoder_dict)
# Out:
# 9

# %%
# referrer_class_df = get_categ_features_counts_dataframe(interactions_filtered_df, 'referrerHostClass')
# print(len(referrer_class_df))
# referrer_class_df

# %%
# referrer_class_encoder_dict = get_categ_features_encoder_dict(referrer_class_df)
# len(referrer_class_encoder_dict)

# %%
encoders_dict = {
    'city': cities_encoder_dict,
#     'region': regions_encoder_dict,
#     'country': countries_encoder_dict,
    'os': os_encoder_dict,
#     'device': devices_encoder_dict,
#     'referrer_class': referrer_class_encoder_dict
}

# %% [markdown]
# ### Processing numeric features

# %%
# %%time
active_time_quantiles = interactions_filtered_df.approxQuantile("top", [0.10, 0.25, 0.50, 0.75, 0.90], 0.01)
print(active_time_quantiles)
# Out:
# [0.0, 13.0, 62.0, 168.0, 393.0]
# CPU times: user 8.11 ms, sys: 12.1 ms, total: 20.2 ms
# Wall time: 805 ms

# %%
active_time_stats_df = interactions_filtered_df.describe('top').toPandas()
active_time_stats_df
# Out:
#   summary                 top
# 0   count             6409658
# 1    mean   227.3538165374814
# 2  stddev  1178.4637884787267
# 3     min                   0
# 4     max               85473

# %%
active_time_mean = float(active_time_stats_df[active_time_stats_df['summary'] == 'mean']['top'].values[0])
active_time_stddev = float(active_time_stats_df[active_time_stats_df['summary'] == 'stddev']['top'].values[0])

# %%
interactions_filtered_df.printSchema()
# Out:
# root
#  |-- full_url: string (nullable = true)
#  |-- dt: string (nullable = true)
#  |-- os_code: integer (nullable = true)
#  |-- loc_id: integer (nullable = true)
#  |-- path: string (nullable = true)
#  |-- referer: string (nullable = true)
#  |-- guid: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- devCode: string (nullable = true)
#  |-- id: long (nullable = true)
#  |-- content: string (nullable = true)
#  |-- created_at_ts: long (nullable = true)
#  |-- teaser: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- keywords: string (nullable = true)
#  |-- time: long (nullable = true)
#  |-- url: string (nullable = true)
#  |-- top: long (nullable = true)
#  |-- article_id: integer (nullable = true)
#  |-- publish_ts: long (nullable = true)

# %%
interactions_filtered_df.select("guid").show(1)
# Out:
# +-------------------+
# |               guid|
# +-------------------+
# |8830407671934495734|
# +-------------------+
# only showing top 1 row

# %%
interactions_filtered_df = interactions_filtered_df.withColumnRenamed("guid", "user_id")

# %%
interactions_filtered_df.printSchema()
# Out:
# root
#  |-- full_url: string (nullable = true)
#  |-- dt: string (nullable = true)
#  |-- os_code: integer (nullable = true)
#  |-- loc_id: integer (nullable = true)
#  |-- path: string (nullable = true)
#  |-- referer: string (nullable = true)
#  |-- user_id: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- devCode: string (nullable = true)
#  |-- id: long (nullable = true)
#  |-- content: string (nullable = true)
#  |-- created_at_ts: long (nullable = true)
#  |-- teaser: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- keywords: string (nullable = true)
#  |-- time: long (nullable = true)
#  |-- url: string (nullable = true)
#  |-- top: long (nullable = true)
#  |-- article_id: integer (nullable = true)
#  |-- publish_ts: long (nullable = true)

# %% [markdown]
# ### Splitting sessions

# %%
'''
schema = T.StructType([
    T.StructField("userId", T.StringType()),
    T.StructField("min_ts", T.IntegerType())
])

@pandas_udf(schema, functionType=PandasUDFType.GROUPED_MAP)
def split_sessions(df):

    result_df = df[['userId']]
    result_df['min_ts'] = df['time'].min()
    
    return result

# %%time
tmp = interactions_filtered_df.groupBy('userId').apply(split_sessions)
tmp.show(100)
'''
# Out:
# '\nschema = T.StructType([\n    T.StructField("userId", T.StringType()),\n    T.StructField("min_ts", T.IntegerType())\n])\n\n@pandas_udf(schema, functionType=PandasUDFType.GROUPED_MAP)\ndef split_sessions(df):\n\n    result_df = df[[\'userId\']]\n    result_df[\'min_ts\'] = df[\'time\'].min()\n    \n    return result\n\n%%time\ntmp = interactions_filtered_df.groupBy(\'userId\').apply(split_sessions)\ntmp.show(100)\n'

# %%
def hash_str_to_int(encoded_bytes_text, digits):
    return int(str(int(hashlib.md5(encoded_bytes_text).hexdigest()[:8], 16))[:digits])

# %%
MAX_SESSION_IDLE_TIME_MS = 30 * 60 * 1000    #30 min

def close_session(session):
    size = len(session)
    
    #Creating and artificial session id based on the first click timestamp and a hash of user id
    first_click = session[0]
    session_id = (int(first_click['timestamp']) * 100) + hash_str_to_int(first_click['user_id'].encode(), 3)
    session_hour = int((first_click['timestamp'] - first_timestamp_ts) / (1000 * 60 * 60)) #Converting timestamp to hours since first timestamp
    
    #Converting to Spark DataFrame Rows, to convert RDD back to DataFrame
    #TODO add 'view' here
    clicks = list([T.Row(**click) for click in session])
    session_dict = {'session_id': session_id,
                    'session_hour': session_hour,
                    'session_size': size,
                    'session_start': first_click['timestamp'],
                    'user_id': first_click['user_id'],
                    'clicks': clicks 
                   }
    session_row = T.Row(**session_dict)
    
    return session_row
        
def transform_interaction(interaction):        
    return {
            'article_id': interaction['article_id'],
            'url': interaction['full_url'],
            'user_id': interaction['user_id'],
            'timestamp': interaction['time'] * 1000, #converting to timestamp
            'active_time_secs': interaction['top'],
#             'country': encode_cat_feature(interaction['country'], encoders_dict['country']),
#             'region': encode_cat_feature(interaction['region'], encoders_dict['region']),
            'city': encode_cat_feature(interaction['loc_id'], encoders_dict['city']),
            'os': encode_cat_feature(interaction['os_code'], encoders_dict['os']),
#             'device': encode_cat_feature(interaction['deviceType'], encoders_dict['device']),
#             'referrer_class': encode_cat_feature(interaction['referrerHostClass'], encoders_dict['referrer_class']),
           }

def split_sessions(group):
    user, interactions = group
    #Ensuring items are sorted by time
    interactions_sorted_by_time = sorted(interactions, key=lambda x: x['time'])
    #Transforming interactions
    interactions_transformed = list(map(transform_interaction, interactions_sorted_by_time))

    
    sessions = []
    session = []        
    first_timestamp = interactions_transformed[0]['timestamp']
    last_timestamp = first_timestamp    
    for interaction in interactions_transformed:
        
        delta_ms = (interaction['timestamp'] - last_timestamp)
        interaction['_elapsed_ms_since_last_click'] = delta_ms 

        if delta_ms <= MAX_SESSION_IDLE_TIME_MS:    
            #Ignoring repeated items in session
            if len(list(filter(lambda x: x['article_id'] == interaction['article_id'], session))) == 0:        
                session.append(interaction)            
        else:
            #If session have at least 2 clicks (minimum for next click predicition)
            if len(session) >= 2:
                session_row = close_session(session)
                sessions.append(session_row)                
            session = [interaction]

        last_timestamp = interaction['timestamp']
            
    if len(session) >= 2:
        session_row = close_session(session)
        sessions.append(session_row)
        
    #if len(sessions) > 1:
    #    raise Exception('USER with more than one session: {}'.format(user))
    
    return list(zip(map(lambda x: x['session_id'], sessions), 
                    sessions))

# %%
'''
#To debug
# %%time
sessions_rdd = interactions_filtered_df.limit(1000).rdd.map(lambda x: (x['userId'], x)).groupByKey() \
                    .collect()

for row in sessions_rdd:
    print(split_sessions(row))
    print()
'''
# Out:
# "\n#To debug\n%%time\nsessions_rdd = interactions_filtered_df.limit(1000).rdd.map(lambda x: (x['userId'], x)).groupByKey()                     .collect()\n\nfor row in sessions_rdd:\n    print(split_sessions(row))\n    print()\n"

# %%
interactions_filtered_df.cache()
# Out:
# DataFrame[full_url: string, dt: string, os_code: int, loc_id: int, path: string, referer: string, user_id: string, category: string, devCode: string, id: bigint, content: string, created_at_ts: bigint, teaser: string, title: string, keywords: string, time: bigint, url: string, top: bigint, article_id: int, publish_ts: bigint]

# %%
# interactions_filtered_df.select("guid").show(1)

# %%
# strn = "7508097301953125944"
# hash_str_to_int(strn.encode(), 3)

# %%
# interactions_filtered_df.printSchema()

# %%
# interactions_filtered_df.select("guid").show()

# %%
interactions_filtered_df = interactions_filtered_df.orderBy("time")

# %%
# interactions_filtered_df.select("time").show(5)
# Out:
# +----------+
# |      time|
# +----------+
# |1554051934|
# |1554052612|
# |1554054411|
# |1554054481|
# |1554054967|
# +----------+
# only showing top 5 rows

# %%
# %%time
sessions_rdd = interactions_filtered_df.rdd.map(lambda x: (x['user_id'], x)).groupByKey() \
                            .flatMap(split_sessions) \
                            .sortByKey() \
                            .map(lambda x: x[1])
# Out:
# CPU times: user 196 ms, sys: 39.6 ms, total: 236 ms
# Wall time: 9min 22s

# %%
# sessions_rdd

# %% [markdown]
# #### Exporting sessions to JSON lines

# %%
# sessions_rdd.toDF().select("session_hour").orderBy("session_hour").distinct().show()

# %%
sessions_sdf = sessions_rdd.toDF()

# %%
# %%time
sessions_sdf.write.partitionBy("session_hour").json(os.path.join(ROOT_PATH,"sessions_processed_by_spark/"))
# Out:
# CPU times: user 33.2 ms, sys: 6.36 ms, total: 39.5 ms
# Wall time: 7.03 s

# %%
sessions_sdf.count()

# %%
def serialize(filename, obj):
    with open(filename, 'wb') as handle:
        pickle.dump(obj, handle)#, protocol=pickle.HIGHEST_PROTOCOL)

# %%
NAR_ENCODERS_PATH  = 'nar_encoders_cafebiz.pickle'
serialize(NAR_ENCODERS_PATH, encoders_dict)

# %%
# !cp {NAR_ENCODERS_PATH} {ROOT_PATH}/pickles/
